# %% [markdown]
# ## Code Hist.

# %% [markdown]
#  - CODE : KIER Data_단순 분리 (전처리 X)
#  - DESC
#     &ensp; : int_Domain 코드의 변경에 따라,
#     &emsp; KIER 에너지 사용량 데이터를 동/층/세대별로 분리 (10분 주기)
#     &emsp; 추가적으로, Raw Data과 세대별 데이터 추출 단계에서, 아래와 같은 작업 진행
#     &emsp;&emsp; 1) Date Column에 대한 유효성 검사 및 이상 Data에 대한 소거
#     &emsp;&emsp; 1-1) Datetime 유효성 확인
#     &emsp;&emsp; 1-2) Datetime 이상치 제거
#     &emsp;&emsp; 2) HOUSE_ID_HO의 해시값을 int_house_num으로 변경 (용량 절감 목적)
#   - DATE
#     &ensp; 2023-10-12 Created
#     &ensp; 2023-11-21 Code 최신화
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 기존 모듈화된 함수 사용
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 기존 KIER 변환 관련 코드를 모두 통합
#     &ensp; 2024-01-19 Code 개선
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선, Raw로 저장
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) HOT (온수 사용량) 전용 Code 작성
#     &ensp; 2024-03-13 Code 개선
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 적산 및 순시사용량 산출 코드 추가
#     &ensp; 2024-07-24 Error Fix : 호실별 사용량 취합시 MemoryError 발생 방지
#     &ensp; 2024-07-25 Code 개선 : HOUSE_ID Feature 도입에 따른 Code 변경
#     &ensp; 2024-07-26 Code 간략화 : ACCU/INST 관련 Src 부분을 각각의 파일로 분리

# %% [markdown]
# ## Code

# %% [markdown]
# ### 01. Init

# %% [markdown]
# #### 01-01. Module Import

# %%
#region Import_Basic Module
## Basic
import os, sys, warnings
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.path.dirname(os.path.abspath('./__file__'))
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('./__file__'))))
warnings.filterwarnings('ignore')

import numpy as np, pandas as pd
from pandas import DataFrame, Series
pd.options.display.float_format = '{:.10f}'.format

import math, random

## Datetime
import time, datetime as dt
from datetime import datetime, date, timedelta

## glob
import glob, requests, json
from glob import glob

## 시각화
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from scipy import stats

## Split, 정규화
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# K-Means 알고리즘
from sklearn.cluster import KMeans, MiniBatchKMeans

# Clustering 알고리즘의 성능 평가 측도
from sklearn import metrics
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score, adjusted_rand_score, silhouette_score, rand_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics.cluster import contingency_matrix

## For Web
import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

import tqdm
from tqdm.notebook import tqdm
#endregion Import_Basic Module

# %%
## Import_DL
str_tar = "tf"
## For Torch
if str_tar == "torch":
    import torch, torch.nn as nn
    from torch.nn.utils import weight_norm
    print("Torch Imported")
## For TF
elif str_tar == "tf":
    import tensorflow as tf, tensorflow_addons as tfa
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    from keras.models import Sequential, load_model
    from keras_flops import get_flops
    print("Tensorflow Imported")
else:
    print("Error : Cannot be used except for Keywords")
    print(" : torch / tf")
# Out:
# Tensorflow Imported

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 8514041830015912304
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 22395486208
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 4148974483685089151
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9"
#  xla_global_id: 416903419]

# %%
tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    print('Using GPU')
    tf.config.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
else : 
  print('Using CPU')
# Out:
# Using GPU

# %%
## Import_Local
from Src_Dev_Common import Data_Datetime as com_date, KMA_Weather as com_KMA, KECO_AirKor as com_KECO, KASI_Holiday as com_Holi, KIER_Usage_M02 as com_KIER_M02

# %% [markdown]
# #### 01-02. Config (Directory, Params)

# %%
## Init_config
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
os.environ["PYTHONHASHSEED"], os.environ['TF_DETERMINISTIC_OPS'] = str(SEED), "1"

# %%
## Define Todate str
str_now_ymd = pd.datetime.now().date()
str_now_y, str_now_m, str_now_d = pd.datetime.now().year, pd.datetime.now().month, pd.datetime.now().day
str_now_hr, str_now_min = pd.datetime.now().hour, pd.datetime.now().minute

print(pd.datetime.now())
print(str(str_now_y) + " / " + str(str_now_m)  + " / " + str(str_now_d))
print(str(str_now_hr) + " : " + str(str_now_min))
# Out:
# 2024-07-30 02:22:37.726721
# 2024 / 7 / 30
# 2 : 22

# %% [markdown]
# ### 02. Data Prepare

# %%
## Dict_Domain
int_domain = 5

## Domain, ACCU/INST Column
str_domain, str_col_accu, str_col_inst = com_KIER_M02.create_domain_str(int_domain)
## Directory Root
str_dirData, str_dir_raw, str_dir_cleansed, str_dirName_bld, str_dirName_h = com_KIER_M02.create_dir_str(str_domain)

## File
str_fileRaw, str_fileRaw_hList = str('KIER_RAW_' + str_domain + '_H_ID_Adopted.csv'), str('KIER_hList_Common.csv')

print(str(os.listdir(str_dirData)) + "\n")
print(os.listdir(str_dirName_h))
# Out:
# 5 : GAS
# ['.ipynb_checkpoints', 'BS_CONFIGURATION_202309251452.csv', 'DATE_1M_2023-10-20.csv', 'KIER 전처리 현황_2024-06-25.xlsx', 'KIER_0_Raw', 'KIER_1_Cleansed', 'KIER_2_BLD', 'KIER_3_H_ELEC', 'KIER_3_H_GAS', 'KIER_3_H_HEAT', 'KIER_3_H_HOT_FLOW', 'KIER_3_H_HOT_HEAT', 'KIER_3_H_WATER', 'KIER_ASOS_WEATHER_DAILY_202309251521.csv', 'KIER_ASOS_WEATHER_HOUR_202309251521.csv', 'KIER_DATA_OLD', 'KIER_ETC', 'KIER_hList_Comparison_2024-06-26.xlsx', 'KIER_List_Table_Column_2023-09-25.xlsx', 'KIER_Query_2023-09-25.txt', 'KMA_ASOS_119_2010_2023_1st_to CSV.csv', '[IITP] 데이터 테이블 정리 (공유 원본).docx']
#
# ['KIER_GAS_561-1-1_ACCU_01_Raw.csv', 'KIER_GAS_561-1-1_INST_01_10min.csv', 'KIER_GAS_561-1-2_ACCU_01_Raw.csv', 'KIER_GAS_561-1-2_INST_01_10min.csv', 'KIER_GAS_561-1-3_ACCU_01_Raw.csv', 'KIER_GAS_561-1-3_INST_01_10min.csv', 'KIER_GAS_561-1-4_ACCU_01_Raw.csv', 'KIER_GAS_561-1-4_INST_01_10min.csv', 'KIER_GAS_561-10-1_ACCU_01_Raw.csv', 'KIER_GAS_561-10-1_INST_01_10min.csv', 'KIER_GAS_561-10-2_ACCU_01_Raw.csv', 'KIER_GAS_561-10-2_INST_01_10min.csv', 'KIER_GAS_561-10-3_ACCU_01_Raw.csv', 'KIER_GAS_561-10-3_INST_01_10min.csv', 'KIER_GAS_561-10-4_ACCU_01_Raw.csv', 'KIER_GAS_561-10-4_INST_01_10min.csv', 'KIER_GAS_561-11-1_ACCU_01_Raw.csv', 'KIER_GAS_561-11-1_INST_01_10min.csv', 'KIER_GAS_561-11-2_ACCU_01_Raw.csv', 'KIER_GAS_561-11-2_INST_01_10min.csv', 'KIER_GAS_561-11-3_ACCU_01_Raw.csv', 'KIER_GAS_561-11-3_INST_01_10min.csv', 'KIER_GAS_561-11-4_ACCU_01_Raw.csv', 'KIER_GAS_561-11-4_INST_01_10min.csv', 'KIER_GAS_561-12-1_ACCU_01_Raw.csv', 'KIER_GAS_561-12-1_INST_01_10min.csv', 'KIER_GAS_561-12-2_ACCU_01_Raw.csv', 'KIER_GAS_561-12-2_INST_01_10min.csv', 'KIER_GAS_561-12-3_ACCU_01_Raw.csv', 'KIER_GAS_561-12-3_INST_01_10min.csv', 'KIER_GAS_561-12-4_ACCU_01_Raw.csv', 'KIER_GAS_561-12-4_INST_01_10min.csv', 'KIER_GAS_561-13-1_ACCU_01_Raw.csv', 'KIER_GAS_561-13-1_INST_01_10min.csv', 'KIER_GAS_561-13-2_ACCU_01_Raw.csv', 'KIER_GAS_561-13-2_INST_01_10min.csv', 'KIER_GAS_561-13-3_ACCU_01_Raw.csv', 'KIER_GAS_561-13-3_INST_01_10min.csv', 'KIER_GAS_561-13-4_ACCU_01_Raw.csv', 'KIER_GAS_561-13-4_INST_01_10min.csv', 'KIER_GAS_561-14-1_ACCU_01_Raw.csv', 'KIER_GAS_561-14-1_INST_01_10min.csv', 'KIER_GAS_561-14-2_ACCU_01_Raw.csv', 'KIER_GAS_561-14-2_INST_01_10min.csv', 'KIER_GAS_561-14-3_ACCU_01_Raw.csv', 'KIER_GAS_561-14-3_INST_01_10min.csv', 'KIER_GAS_561-14-4_ACCU_01_Raw.csv', 'KIER_GAS_561-14-4_INST_01_10min.csv', 'KIER_GAS_561-15-1_ACCU_01_Raw.csv', 'KIER_GAS_561-15-1_INST_01_10min.csv', 'KIER_GAS_561-15-2_ACCU_01_Raw.csv', 'KIER_GAS_561-15-2_INST_01_10min.csv', 'KIER_GAS_561-15-3_ACCU_01_Raw.csv', 'KIER_GAS_561-15-3_INST_01_10min.csv', 'KIER_GAS_561-15-4_ACCU_01_Raw.csv', 'KIER_GAS_561-15-4_INST_01_10min.csv', 'KIER_GAS_561-16-1_ACCU_01_Raw.csv', 'KIER_GAS_561-16-1_INST_01_10min.csv', 'KIER_GAS_561-16-2_ACCU_01_Raw.csv', 'KIER_GAS_561-16-2_INST_01_10min.csv', 'KIER_GAS_561-16-3_ACCU_01_Raw.csv', 'KIER_GAS_561-16-3_INST_01_10min.csv', 'KIER_GAS_561-16-4_ACCU_01_Raw.csv', 'KIER_GAS_561-16-4_INST_01_10min.csv', 'KIER_GAS_561-17-1_ACCU_01_Raw.csv', 'KIER_GAS_561-17-1_INST_01_10min.csv', 'KIER_GAS_561-17-2_ACCU_01_Raw.csv', 'KIER_GAS_561-17-2_INST_01_10min.csv', 'KIER_GAS_561-17-3_ACCU_01_Raw.csv', 'KIER_GAS_561-17-3_INST_01_10min.csv', 'KIER_GAS_561-17-4_ACCU_01_Raw.csv', 'KIER_GAS_561-17-4_INST_01_10min.csv', 'KIER_GAS_561-18-1_ACCU_01_Raw.csv', 'KIER_GAS_561-18-1_INST_01_10min.csv', 'KIER_GAS_561-18-2_ACCU_01_Raw.csv', 'KIER_GAS_561-18-2_INST_01_10min.csv', 'KIER_GAS_561-18-3_ACCU_01_Raw.csv', 'KIER_GAS_561-18-3_INST_01_10min.csv', 'KIER_GAS_561-18-4_ACCU_01_Raw.csv', 'KIER_GAS_561-18-4_INST_01_10min.csv', 'KIER_GAS_561-2-1_ACCU_01_Raw.csv', 'KIER_GAS_561-2-1_INST_01_10min.csv', 'KIER_GAS_561-2-2_ACCU_01_Raw.csv', 'KIER_GAS_561-2-2_INST_01_10min.csv', 'KIER_GAS_561-2-3_ACCU_01_Raw.csv', 'KIER_GAS_561-2-3_INST_01_10min.csv', 'KIER_GAS_561-2-4_ACCU_01_Raw.csv', 'KIER_GAS_561-2-4_INST_01_10min.csv', 'KIER_GAS_561-3-1_ACCU_01_Raw.csv', 'KIER_GAS_561-3-1_INST_01_10min.csv', 'KIER_GAS_561-3-2_ACCU_01_Raw.csv', 'KIER_GAS_561-3-2_INST_01_10min.csv', 'KIER_GAS_561-3-3_ACCU_01_Raw.csv', 'KIER_GAS_561-3-3_INST_01_10min.csv', 'KIER_GAS_561-3-4_ACCU_01_Raw.csv', 'KIER_GAS_561-3-4_INST_01_10min.csv', 'KIER_GAS_561-4-1_ACCU_01_Raw.csv', 'KIER_GAS_561-4-1_INST_01_10min.csv', 'KIER_GAS_561-4-2_ACCU_01_Raw.csv', 'KIER_GAS_561-4-2_INST_01_10min.csv', 'KIER_GAS_561-4-3_ACCU_01_Raw.csv', 'KIER_GAS_561-4-3_INST_01_10min.csv', 'KIER_GAS_561-4-4_ACCU_01_Raw.csv', 'KIER_GAS_561-4-4_INST_01_10min.csv', 'KIER_GAS_561-5-1_ACCU_01_Raw.csv', 'KIER_GAS_561-5-1_INST_01_10min.csv', 'KIER ...

# %% [markdown]
# #### 02-01. KIER (hList)

# %%
## Load Dataset (hList)
## "KIER_01-01_Data_hList.ipynb"로부터 만들어진 Bld/F/H List
df_kier_hList = pd.read_csv(str_dir_raw + str_fileRaw_hList, index_col = 0)
# print(df_kier_hList.shape, ' /// ', df_kier_hList.columns)
# df_kier_hList

# %% [markdown]
# #### 02-02. KIER (Energy Usage)

# %% [markdown]
# ##### Case 01. "METER_DATE" Cleansing이 완료되지 않은 경우

# %%
## ▶ Load Dataset (Energy Usage)
df_raw = pd.read_csv(str_dir_raw + str_fileRaw, index_col = 0)
print(df_raw.shape, ' /// ', df_raw.columns)
df_raw
# Out:
# (52379163, 3)  ///  Index(['METER_DATE', 'HOUSE_ID', 'GAS_ACCU_FLOW'], dtype='object')
#                    METER_DATE  HOUSE_ID  GAS_ACCU_FLOW
# 823       2022-08-10 15:30:09   561-1-1   0.0000000000
# 824       2022-08-24 10:00:26   561-1-1   0.0000000000
# 825       2022-09-19 23:54:11   561-1-1   0.1200000000
# 826       2022-09-20 19:14:12   561-1-1   0.1200000000
# 827       2022-09-20 20:14:12   561-1-1   0.1200000000
# ...                       ...       ...            ...
# 52380804  2024-06-24 09:36:59  563-24-2   0.1100000000
# 52380805  2024-06-24 09:46:59  563-24-2   0.1100000000
# 52380806  2024-06-24 09:56:59  563-24-2   0.1100000000
# 52380807  2024-06-24 10:06:59  563-24-2   0.1100000000
# 52380808  2024-06-24 10:16:59  563-24-2   0.1100000000
#
# [52379163 rows x 3 columns]

# %%
## 1) Date Column에 대한 유효성 검사 및 이상 Data에 대한 소거
## 1-1) Datetime 유효성 확인
list_errValues = com_date.list_invalidDate(df_raw, 'METER_DATE')
print(len(list_errValues))

## 1-2) Datetime 이상치 제거
for i in range(len(list_errValues) - 1, -1, -1) : df_raw = df_raw.drop(index = list_errValues[i], axis = 0)

print(df_raw.shape, ' /// ', df_raw.columns)
df_raw
# Out:
# (52379163, 3)
# 0
# []
# 0
# (52379163, 3)  ///  Index(['METER_DATE', 'HOUSE_ID', 'GAS_ACCU_FLOW'], dtype='object')
#                    METER_DATE  HOUSE_ID  GAS_ACCU_FLOW
# 823       2022-08-10 15:30:09   561-1-1   0.0000000000
# 824       2022-08-24 10:00:26   561-1-1   0.0000000000
# 825       2022-09-19 23:54:11   561-1-1   0.1200000000
# 826       2022-09-20 19:14:12   561-1-1   0.1200000000
# 827       2022-09-20 20:14:12   561-1-1   0.1200000000
# ...                       ...       ...            ...
# 52380804  2024-06-24 09:36:59  563-24-2   0.1100000000
# 52380805  2024-06-24 09:46:59  563-24-2   0.1100000000
# 52380806  2024-06-24 09:56:59  563-24-2   0.1100000000
# 52380807  2024-06-24 10:06:59  563-24-2   0.1100000000
# 52380808  2024-06-24 10:16:59  563-24-2   0.1100000000
#
# [52379163 rows x 3 columns]

# %%
## Cleansed Data를 저장
str_file = str('KIER_RAW_' + str_domain + '_Cleansed.csv')
df_raw.to_csv(str_dir_raw + str_file)
df_raw
# Out:
#                    METER_DATE  HOUSE_ID  GAS_ACCU_FLOW
# 823       2022-08-10 15:30:09   561-1-1   0.0000000000
# 824       2022-08-24 10:00:26   561-1-1   0.0000000000
# 825       2022-09-19 23:54:11   561-1-1   0.1200000000
# 826       2022-09-20 19:14:12   561-1-1   0.1200000000
# 827       2022-09-20 20:14:12   561-1-1   0.1200000000
# ...                       ...       ...            ...
# 52380804  2024-06-24 09:36:59  563-24-2   0.1100000000
# 52380805  2024-06-24 09:46:59  563-24-2   0.1100000000
# 52380806  2024-06-24 09:56:59  563-24-2   0.1100000000
# 52380807  2024-06-24 10:06:59  563-24-2   0.1100000000
# 52380808  2024-06-24 10:16:59  563-24-2   0.1100000000
#
# [52379163 rows x 3 columns]

# %% [markdown]
# ##### Case 02. "METER_DATE" Cleansing이 완료된 경우

# %%
str_fileCleansed = str('KIER_RAW_' + str_domain + '_Cleansed.csv')
df_raw = pd.read_csv(str_dir_raw + str_fileCleansed, index_col = 0)
print(df_raw.shape, ' /// ', df_raw.columns)
df_raw
# Out:
# (52379163, 3)  ///  Index(['METER_DATE', 'HOUSE_ID', 'GAS_ACCU_FLOW'], dtype='object')
#                    METER_DATE  HOUSE_ID  GAS_ACCU_FLOW
# 823       2022-08-10 15:30:09   561-1-1   0.0000000000
# 824       2022-08-24 10:00:26   561-1-1   0.0000000000
# 825       2022-09-19 23:54:11   561-1-1   0.1200000000
# 826       2022-09-20 19:14:12   561-1-1   0.1200000000
# 827       2022-09-20 20:14:12   561-1-1   0.1200000000
# ...                       ...       ...            ...
# 52380804  2024-06-24 09:36:59  563-24-2   0.1100000000
# 52380805  2024-06-24 09:46:59  563-24-2   0.1100000000
# 52380806  2024-06-24 09:56:59  563-24-2   0.1100000000
# 52380807  2024-06-24 10:06:59  563-24-2   0.1100000000
# 52380808  2024-06-24 10:16:59  563-24-2   0.1100000000
#
# [52379163 rows x 3 columns]

# %% [markdown]
# #### 02-02. Data Separation
# 각 세대별 적산값을 파일로 저장

# %%
## ▶ 각 세대별 적산값을 Column으로 분리 및 각 CSV로 저장
dt_start, dt_end = 0, 0

list_HID = df_kier_hList['HOUSE_ID'].drop_duplicates()
for house in list_HID:
    print(str(house) + " H")
    str_col_accu_h = str_col_accu + "_" + house

    df_h_tmp = df_raw[(df_raw['HOUSE_ID'] == house)].reset_index()
    df_h_tmp['METER_DATE'] = pd.to_datetime(df_h_tmp['METER_DATE'])
    df_h_tmp = com_date.create_col_ymdhm(df_h_tmp, 'METER_DATE')

    ## METER_DATE의 Minute이 10분 단위가 아닌 경우, 10분 단위로 변경
    for i in range(0, len(df_h_tmp)) : df_h_tmp['MINUTE'].iloc[i] = (math.floor(df_h_tmp['MINUTE'].iloc[i]/10))*10
    
    int_len_start = len(df_h_tmp)
    ## NaN값에 대한 Interpolation
    ## 1) 변경된 시간값을 기반으로 "METER_DATE" Column을 다시 생성 
    ## 2) 생성된 "METER_DATE" Column을 기반으로 중복 제거 (시간 중첩으로 인한 MemoryError 방지)
    ## 3) 열 정리 : ['METER_DATE', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', str_col_accu]
    ## 4) 적산 Nan값을 제거
    ## 5) 사용량 Column을 str_col_accu_h로 변경 (추후 취합 목적)
    df_h_tmp = com_date.create_col_datetime(df_h_tmp, 'METER_DATE', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE')
    df_h_tmp = df_h_tmp.drop_duplicates(subset = 'METER_DATE')[['METER_DATE', 'YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', str_col_accu]].dropna().rename(columns = {str_col_accu : str_col_accu_h})

    ## ▶ 최적의 Period 계산 및 dt_start, dt_end 변수에 저장
    if dt_start == 0 : dt_start = df_h_tmp['METER_DATE'].min()
    else : 
        if dt_start < df_h_tmp['METER_DATE'].min(): dt_start = df_h_tmp['METER_DATE'].min()
    
    if dt_end == 0 : dt_end = df_h_tmp['METER_DATE'].max()
    else : 
        if dt_start > df_h_tmp['METER_DATE'].max() : dt_start = df_h_tmp['METER_DATE'].max()

    
    ## 만약 작업 전후로 Data Shape이 변동되었다면, 변동사항 출력
    int_len_end = len(df_h_tmp)
    if int_len_start != int_len_end: print(int_len_start, ' / ', int_len_end)

    ## 해당 Dataframe을 각 CSV로 Export
    str_df_h = str('KIER_' + str_domain + '_' + str(house) + '_ACCU_01_Raw.csv')
    df_h_tmp.to_csv(str_dirName_h + str_df_h)

print(dt_start, ' / ',dt_end)
# Out:
# 561-1-1 H
# 179956  /  89906
# 561-1-2 H
# 173802  /  85459
# 561-1-3 H
# 179750  /  87827
# 561-1-4 H
# 167066  /  81921
# 561-2-1 H
# 179754  /  88401
# 561-2-2 H
# 171822  /  85506
# 561-2-3 H
# 173418  /  85800
# 561-2-4 H
# 179908  /  89936
# 561-3-1 H
# 167302  /  83253
# 561-3-2 H
# 173964  /  86909
# 561-3-3 H
# 170826  /  85374
# 561-3-4 H
# 170872  /  85340
# 561-4-1 H
# 176260  /  88119
# 561-4-2 H
# 179968  /  89938
# 561-4-3 H
# 175796  /  87684
# 561-4-4 H
# 171328  /  85551
# 561-5-1 H
# 173718  /  85370
# 561-5-2 H
# 172786  /  85377
# 561-5-3 H
# 173820  /  84436
# 561-5-4 H
# 179958  /  89881
# 561-6-1 H
# 174320  /  86263
# 561-6-2 H
# 159192  /  79190
# 561-6-3 H
# 179404  /  89667
# 561-6-4 H
# 171038  /  85483
# 561-7-1 H
# 173920  /  86895
# 561-7-2 H
# 168294  /  83866
# 561-7-3 H
# 169052  /  83744
# 561-7-4 H
# 171664  /  85630
# 561-8-1 H
# 170742  /  84830
# 561-8-2 H
# 178748  /  88547
# 561-8-3 H
# 180014  /  89810
# 561-8-4 H
# 162160  /  81002
# 561-9-1 H
# 179418  /  88567
# 561-9-2 H
# 173158  /  86383
# 561-9-3 H
# 172200  /  86031
# 561-9-4 H
# 168598  /  84226
# 561-10-1 H
# 172600  /  86247
# 561-10-2 H
# 179986  /  89716
# 561-10-3 H
# 177212  /  87615
# 561-10-4 H
# 174376  /  87144
# 561-11-1 H
# 173778  /  85929
# 561-11-2 H
# 173086  /  86243
# 561-11-3 H
# 175236  /  86871
# 561-11-4 H
# 171438  /  85688
# 561-12-1 H
# 169870  /  84701
# 561-12-2 H
# 173058  /  85997
# 561-12-3 H
# 179874  /  89032
# 561-12-4 H
# 180000  /  89932
# 561-13-1 H
# 169500  /  83736
# 561-13-2 H
# 173910  /  86851
# 561-13-3 H
# 170330  /  85007
# 561-13-4 H
# 176914  /  87360
# 561-14-1 H
# 173652  /  86663
# 561-14-2 H
# 179948  /  89831
# 561-14-3 H
# 179552  /  89705
# 561-14-4 H
# 180018  /  89899
# 561-15-1 H
# 172304  /  86083
# 561-15-2 H
# 179856  /  89787
# 561-15-3 H
# 178146  /  88987
# 561-15-4 H
# 167706  /  83727
# 561-16-1 H
# 168348  /  83975
# 561-16-2 H
# 179842  /  89887
# 561-16-3 H
# 174716  /  86991
# 561-16-4 H
# 176944  /  88355
# 561-17-1 H
# 179800  /  89083
# 561-17-2 H
# 179432  /  89715
# 561-17-3 H
# 179814  /  89864
# 561-17-4 H
# 174854  /  86664
# 561-18-1 H
# 179940  /  89118
# 561-18-2 H
# 179898  /  89750
# 561-18-3 H
# 179990  /  89942
# 561-18-4 H
# 171014  /  85436
# 562-1-1 H
# 179886  /  89922
# 562-1-2 H
# 167128  /  82160
# 562-1-3 H
# 179882  /  89867
# 562-1-4 H
# 165756  /  82745
# 562-1-5 H
# 171514  /  83126
# 562-1-6 H
# 178938  /  86025
# 562-2-1 H
# 179552  /  89551
# 562-2-2 H
# 170438  /  84892
# 562-2-3 H
# 173418  /  85976
# 562-2-4 H
# 179728  /  89649
# 562-2-5 H
# 179788  /  88386
# 562-2-6 H
# 178050  /  88726
# 562-3-1 H
# 176256  /  87590
# 562-3-2 H
# 167104  /  83054
# 562-3-3 H
# 179760  /  86745
# 562-3-4 H
# 179682  /  89480
# 562-3-5 H
# 179626  /  87887
# 562-3-6 H
# 179562  /  88199
# 562-4-1 H
# 179880  /  89298
# 562-4-2 H
# 178882  /  88730
# 562-4-3 H
# 176546  /  87091
# 562-4-4 H
# 179514  /  88498
# 562-4-5 H
# 179894  /  88118
# 562-4-6 H
# 179768  /  89443
# 562-5-1 H
# 165394  /  81457
# 562-5-2 H
# 167450  /  83289
# 562-5-3 H
# 168038  /  82973
# 562-5-4 H
# 166032  /  82944
# 562-5-5 H
# 172126  /  85830
# 562-5-6 H
# 179918  /  89857
# 562-6-1 H
# 179036  /  88706
# 562-6-2 H
# 179954  /  89956
# 562-6-3 H
# 179566  /  88867
# 562-6-4 H
# 163784  /  81790
# 562-6-5 H
# 171686  /  85751
# 562-6-6 H
# 179826  /  89867
# 562-7-1 H
# 179800  /  89844
# 562-7-2 H
# 179842  /  88414
# 562-7-3 H
# 179140  /  89397
# 562-7-4 H
# 179830  /  89815
# 562-7-5 H
# 179944  /  88866
# 562-7-6 H
# 179866  /  89814
# 562-8-1 H
# 168262  /  83864
# 562-8-2 H
# 179680  /  89666
# 562-8-3 H
# 170978  /  85257
# 562-8-4 H
# 179600  /  89683
# 562-8-5 H
# 179890  /  89658
# 562-8-6 H
# 179938  /  89890
# 562-9-1 H
# 172500  /  83958
# 562-9-2 H
# 179886  /  88241
# 562-9-3 H
# 179742  /  89573
# 562-9-4 H
# 179958  /  89848
# 562-9-5 H
# 170214  /  84804
# 562-9-6 H
# 175838  /  86928
# 562-10-1 H
# 179972  /  89490
# 562-10-2 H
# 179874  /  89556
# 562-10-3 H
# 169988  /  84719
# 562-10-4 H
# 171712  /  83224
# 562-10-5 H
# 179902  /  89557
# 562-10-6 H
# 179496  /  89117
# 562-11-1 H
# 179868  /  89612
# 562-11-2 H
# 179982  /  89671
# 562-11-3 H
# 168156  /  83594
# 562-11-4 H
# 179706  /  89776
# 562-11-5 H
# 177886  /  88755
# 562-11-6 H
# 186004  /  89797
# 562-12-1 H
# 179618  /  89690
# 562-12-2 H
# 179790  /  89862
# 562-12-3 H
# 179964  /  89539
# 562-12-4 H
# 179796  /  89420
# 562-12-5 H
# 179942  /  89860
# 562-12-6 H
# 169614  /  84750
# 562-13-1 H
# 179796  /  88216
# 562-13-2 H
# 179872  /  89881
# 562-13-3 H
# 179780  /  87826
# 562-13-4 H
# 171186  /  84514
# 562-13-5 H
# 178618  /  89228
# 562-13-6 H
# 168228  /  84047
# 562-14-1 H
# 173644  /  86742
# 562-14-2 H
# 179228  /  89324
# 562-14-3 H
# 179792  /  88668
# 562-14-4 H
# 179866  /  89642
# 562-14-5 H
# 181064  /  89176
# 562-14-6 H
# 167992  /  83907
# 562-15-1 H
# 179826  /  89808
# 562-15-2 H
# 179450  /  89515
# 562-15-3 H
# 166806  /  80843
# 562-15-4 H
# 179854  /  87265
# 562-15-5 H
# 179902  /  88438
# 562-15-6 H
# 173090  /  84658
# 562-16-1 H
# 179572  /  89355
# 562-16-2 H
# 179866  /  89676
# 562-16-3 H
# 172304  /  86002
# 562-16-4 H
# 180080  /  89827
# 562-16-5 H
# 179494  /  89551
# 562-16-6 H
# 179852  /  89826
# 562-17-1 H
# 179856  /  89747
# 562-17-2 H
# 179290  /  89512
# 562-17-3 H
# 179792  /  89666
# 562-17-4 H
# 179834  /  89779
# 562-17-5 H
# 173968  /  86878
# 562-17-6 H
# 179904  /  89930
# 562-18-1 H
# 179838  /  89815
# 562-18-2 H
# 179852  /  89900
# 562-18-3 H
# 179930  /  89841
# 562-18-4 H
# 179880  /  89779
# 562-18-5 H
# 181274  /  89586
# 562-18-6 H
# 170304  /  84998
# 562-19-1 H
# 161800  /  80794
# 562-19-2 H
# 179882  /  89271
# 562-19-3 H
# 179820  /  88014
# 562-19-4 H
# 179916  /  89955
# 562-19-5 H
# 171746  /  83623
# 562-19-6 H
# 168628  /  82021
# 562-20-1 H
# 168326  /  83768
# 562-20-2 H
# 172194  /  85700
# 562-20-3 H
# 179378  /  88982
# 562-20-4 H
# 179932  /  88048
# 562-20-5 H
# 179182  /  89337
# 562-20-6 H
# 178098  /  88729
# 562-21-1 H
# 174302  /  86757
# 562-21-2 H
# 169326  /  82095
# 562-21-3 H
# 177360  /  88560
# 562-21-4 H
# 172248  /  85541
# 562-21-5 H
# 179972  /  87098
# 562-21-6 H
# 179878  /  89861
# 562-22-1 H
# 179918  /  89635
# 562-22-2 H
# 179834  /  89809
# 562-22-3 H
# 176584  /  88180
# 562-22-4 H
# 178850  /  88305
# 562-22-5 H
# 179520  /  89671
# 562-22-6 H
# 168504  /  84030
# 562-23-1 H
# 179934  /  89851
# 562-23-2 H
# 178710  /  89251
# 562-23-3 H
# 179892  /  89914
# 562-23-4 H
# 179766  /  89752
# 562-24-1 H
# 178776  /  89211
# 562-24-2 H
# 179886  /  89862
# 563-1-1 H
# 179514  /  89709
# 563-1-2 H
# 176782  /  88353
# 563-1-3 H
# 164508  /  82157
# 563-1-4 H
# 179540  /  89752
# 563-1-5 H
# 179010  /  89473
# 563-1-6 H
# 179884  /  89755
# 563-2-1 H
# 179388  /  89679
# 563-2-2 H
# 174902  /  87358
# 563-2-3 H
# 178246  /  88880
# 563-2-4 H
# 178010  /  88976
# 563-2-5 H
# 179056  /  89485
# 563-2-6 H
# 179022  /  89483
# 563-3-1 H
# 175354  /  87603
# 563-3-2 H
# 179276  /  89598
# 563-3-3 H
# 173392  /  86637
# 563-3-4 H
# 178578  /  89057
# 563-3-5 H
# 179822  /  89841
# 563-3-6 H
# 179452  /  89679
# 563-4-1 H
# 179648  /  89734
# 563-4-2 H
# 173836  /  86822
# 563-4-3 H
# 179892  /  89919
# 563-4-4 H
# 179186  /  89468
# 563-4-5 H
# 179480  /  89274
# 563-4-6 H
# 179390  /  89541
# 563-5-1 H
# 172864  /  86309
# 563-5-2 H
# 179560  /  87893
# 563-5-3 H
# 176766  /  88272
# 563-5-4 H
# 179552  /  89607
# 563-5-5 H
# 179310  /  88478
# 563-5-6 H
# 174592  /  86321
# 563-6-1 H
# 179874  /  89912
# 563-6-2 H
# 177570  /  88572
# 563-6-3 H
# 175548  /  87628
# 563-6-4 H
# 179766  /  89382
# 563-6-5 H
# 172984  /  86332
# 563-6-6 H
# 129318  /  88023
# 563-7-1 H
# 89716  /  89710
# 563-7-2 H
# 89999  /  89992
# 563-7-3 H
# 89841  /  89749
# 563-7-4 H
# 89818  /  89751
# 563-7-5 H
# 89837  /  89143
# 563-7-6 H
# 89770  /  89568
# 563-8-1 H
# 89799  /  89527
# 563-8-2 H
# 89991  /  89983
# 563-8-3 H
# 90089  /  89747
# 563-8-4 H
# 89710  /  89693
# 563-8-5 H
# 89896  /  89884
# 563-8-6 H
# 89807  /  89793
# 563-9-1 H
# 89919  /  88939
# 563-9-2 H
# 90064  /  89736
# 563-9-3 H
# 89076  /  88811
# 563-9-4 H
# 563-9-5 H
# 85336  /  85313
# 563-9-6 H
# 89321  /  89225
# 563-10-1 H
# 88911  /  88758
# 563-10-2 H
# 89922  /  89914
# 563-10-3 H
# 90930  /  89272
# 563-10-4 H
# 89860  /  89225
# 563-10-5 H
# 89782  /  89773
# 563-10-6 H
# 89859  /  89681
# 563-11-1 H
# 89965  /  88896
# 563-11-2 H
# 89559  /  89126
# 563-11-3 H
# 89937  /  89921
# 563-11-4 H
# 89630  /  89598
# 563-11-5 H
# 90389  /  89598
# 563-11-6 H
# 89059  /  88636
# 563-12-1 H
# 86765  /  86237
# 563-12-2 H
# 89979  /  89957
# 563-12-3 H
# 89637  /  89521
# 563-12-4 H
# 89690  /  89524
# 563-12-5 H
# 89237  /  89156
# 563-12-6 H
# 84110  /  82365
# 563-13-1 H
# 88778  /  88692
# 563-13-2 H
# 89331  /  89144
# 563-13-3 H
# 89377  /  87583
# 563-13-4 H
# 89354  /  89261
# 563-13-5 H
# 89925  /  89858
# 563-13-6 H
# 89525  /  89421
# 563-14-1 H
# 88545  /  88393
# 563-14-2 H
# 89823  /  89136
# 563-14-3 H
# 89648  /  89598
# 563-14-4 H
# 89793  /  88247
# 563-14-5 H
# 89148  /  89076
# 563-14-6 H
# 88755  /  88722
# 563-15-1 H
# 88184  /  88065
# 563-15-2 H
# 89967  /  89924
# 563-15-3 H
# 563-15-4 H
# 89838  /  88680
# 563-15-5 H
# 89288  /  87549
# 563-15-6 H
# 85059  /  84931
# 563-16-1 H
# 85574  /  85358
# 563-16-2 H
# 85601  /  85482
# 563-16-3 H
# 88955  /  88463
# 563-16-4 H
# 88947  /  88015
# 563-16-5 H
# 89871  /  89293
# 563-16-6 H
# 89191  /  86632
# 563-17-1 H
# 89905  /  89766
# 563-17-2 H
# 89772  /  89658
# 563-17-3 H
# 87126  /  84916
# 563-17-4 H
# 89412  /  87685
# 563-17-5 H
# 88438  /  87665
# 563-17-6 H
# 82984  /  82575
# 563-18-1 H
# 89816  /  89794
# 563-18-2 H
# 89918  /  89913
# 563-18-3 H
# 87097  /  86005
# 563-18-4 H
# 89288  /  89227
# 563-18-5 H
# 89158  /  87981
# 563-18-6 H
# 89843  /  89419
# 563-19-1 H
# 89223  /  89222
# 563-19-2 H
# 87911  /  87908
# 563-19-3 H
# 89223  /  89134
# 563-19-4 H
# 89986  /  89984
# 563-19-5 H
# 84778  /  84291
# 563-19-6 H
# 88217  /  88146
# 563-20-1 H
# 88809  /  88746
# 563-20-2 H
# 89984  /  89957
# 563-20-3 H
# 89610  /  89586
# 563-20-4 H
# 86157  /  86136
# 563-20-5 H
# 87552  /  86678
# 563-20-6 H
# 89847  /  89751
# 563-21-1 H
# 89646  /  89403
# 563-21-2 H
# 89448  /  88114
# 563-21-3 H
# 85484  /  84207
# 563-21-4 H
# 89853  /  89660
# 563-21-5 H
# 89932  /  88909
# 563-21-6 H
# 89973  /  89954
# 563-22-1 H
# 89888  /  89159
# 563-22-2 H
# 89002  /  88073
# 563-22-3 H
# 89410  /  87279
# 563-22-4 H
# 83600  /  83477
# 563-22-5 H
# 90001  /  89958
# 563-22-6 H
# 89939  /  89923
# 563-23-1 H
# 86641  /  85184
# 563-23-2 H
# 89409  /  87898
# 563-23-3 H
# 89895  /  89328
# 563-23-4 H
# 89797  /  89562
# 563-24-1 H
# 83918  /  83078
# 563-24-2 H
# 89377  /  87736
# 2022-08-26 20:50:00  /  2024-06-24 10:10:00

# %%
## 계산된 Period에 대한 Date Dataframe 생성
df_kier_h_Combined = com_date.create_df_dt(pd.DataFrame(), 'METER_DATE', dt_start, dt_end, '10min')[['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE']]

## METER_DATE의 Minute이 10분 단위가 아닌 경우, 10분 단위로 변경
for i in range(0, len(df_kier_h_Combined)) : df_kier_h_Combined['MINUTE'].iloc[i] = (math.floor(df_kier_h_Combined['MINUTE'].iloc[i]/10))*10
df_kier_h_Combined
# Out:
#        YEAR  MONTH  DAY  HOUR  MINUTE
# 0      2022      8   26    20      50
# 1      2022      8   26    21       0
# 2      2022      8   26    21      10
# 3      2022      8   26    21      20
# 4      2022      8   26    21      30
# ...     ...    ...  ...   ...     ...
# 96124  2024      6   24     9      30
# 96125  2024      6   24     9      40
# 96126  2024      6   24     9      50
# 96127  2024      6   24    10       0
# 96128  2024      6   24    10      10
#
# [96129 rows x 5 columns]

# %% [markdown]
# ### 03. 적산 사용량
# 모든 호실의 사용량을 변수화하여 한 데이터셋에 Combine

# %%
list_HID = df_kier_hList['HOUSE_ID'].drop_duplicates()
for house in list_HID:
    print(str(house) + " H")

    str_col_accu_h = str_col_accu + "_" + house
    str_file = 'KIER_' + str_domain + '_' + str(house) + '_ACCU_01_Raw.csv'
    df_h_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0).reset_index()[['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', str_col_accu_h]]

    df_kier_h_Combined = pd.merge(df_kier_h_Combined, df_h_tmp, how = 'left', on = ['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE'])
    print(df_kier_h_Combined.shape, ' /// ', df_kier_h_Combined.columns)

str_file = 'KIER_' + str_domain + '_ACCU_10MIN.csv'
df_kier_h_Combined.to_csv(str_dirName_h + str_file)
print(df_kier_h_Combined.shape, ' /// ', df_kier_h_Combined.columns)
df_kier_h_Combined
# Out:
# 561-1-1 H
# (96129, 6)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1'], dtype='object')
# 561-1-2 H
# (96129, 7)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2'],
#       dtype='object')
# 561-1-3 H
# (96129, 8)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3'],
#       dtype='object')
# 561-1-4 H
# (96129, 9)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4'],
#       dtype='object')
# 561-2-1 H
# (96129, 10)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1'],
#       dtype='object')
# 561-2-2 H
# (96129, 11)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2'],
#       dtype='object')
# 561-2-3 H
# (96129, 12)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3'],
#       dtype='object')
# 561-2-4 H
# (96129, 13)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4'],
#       dtype='object')
# 561-3-1 H
# (96129, 14)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1'],
#       dtype='object')
# 561-3-2 H
# (96129, 15)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2'],
#       dtype='object')
# 561-3-3 H
# (96129, 16)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3'],
#       dtype='object')
# 561-3-4 H
# (96129, 17)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4'],
#       dtype='object')
# 561-4-1 H
# (96129, 18)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1'],
#       dtype='object')
# 561-4-2 H
# (96129, 19)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2'],
#       dtype='object')
# 561-4-3 H
# (96129, 20)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3'],
#       dtype='object')
# 561-4-4 H
# (96129, 21)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4'],
#       dtype='object')
# 561-5-1 H
# (96129, 22)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1'],
#       dtype='object')
# 561-5-2 H
# (96129, 23)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2'],
#       dtype='object')
# 561-5-3 H
# (96129, 24)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3'],
#       dtype='object')
# 561-5-4 H
# (96129, 25)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4'],
#       dtype='object')
# 561-6-1 H
# (96129, 26)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1'],
#       dtype='object')
# 561-6-2 H
# (96129, 27)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2'],
#       dtype='object')
# 561-6-3 H
# (96129, 28)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3'],
#       dtype='object')
# 561-6-4 H
# (96129, 29)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4'],
#       dtype='object')
# 561-7-1 H
# (96129, 30)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1'],
#       dtype='object')
# 561-7-2 H
# (96129, 31)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2'],
#       dtype='object')
# 561-7-3 H
# (96129, 32)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3'],
#       dtype='object')
# 561-7-4 H
# (96129, 33)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4'],
#       dtype='object')
# 561-8-1 H
# (96129, 34)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1'],
#       dtype='object')
# 561-8-2 H
# (96129, 35)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2'],
#       dtype='object')
# 561-8-3 H
# (96129, 36)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3'],
#       dtype='object')
# 561-8-4 H
# (96129, 37)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4'],
#       dtype='object')
# 561-9-1 H
# (96129, 38)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1'],
#       dtype='object')
# 561-9-2 H
# (96129, 39)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2'],
#       dtype='object')
# 561-9-3 H
# (96129, 40)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3'],
#       dtype='object')
# 561-9-4 H
# (96129, 41)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4'],
#       dtype='object')
# 561-10-1 H
# (96129, 42)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1'],
#       dtype='object')
# 561-10-2 H
# (96129, 43)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2'],
#       dtype='object')
# 561-10-3 H
# (96129, 44)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3'],
#       dtype='object')
# 561-10-4 H
# (96129, 45)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4'],
#       dtype='object')
# 561-11-1 H
# (96129, 46)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1'],
#       dtype='object')
# 561-11-2 H
# (96129, 47)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2'],
#       dtype='object')
# 561-11-3 H
# (96129, 48)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3'],
#       dtype='object')
# 561-11-4 H
# (96129, 49)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4'],
#       dtype='object')
# 561-12-1 H
# (96129, 50)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1'],
#       dtype='object')
# 561-12-2 H
# (96129, 51)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2'],
#       dtype='object')
# 561-12-3 H
# (96129, 52)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3'],
#       dtype='object')
# 561-12-4 H
# (96129, 53)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3',
#        'GAS_ACCU_FLOW_561-12-4'],
#       dtype='object')
# 561-13-1 H
# (96129, 54)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3',
#        'GAS_ACCU_FLOW_561-12-4', 'GAS_ACCU_FLOW_561-13-1'],
#       dtype='object')
# 561-13-2 H
# (96129, 55)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3',
#        'GAS_ACCU_FLOW_561-12-4', 'GAS_ACCU_FLOW_561-13-1',
#        'GAS_ACCU_FLOW_561-13-2'],
#       dtype='object')
# 561-13-3 H
# (96129, 56)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3',
#        'GAS_ACCU_FLOW_561-12-4', 'GAS_ACCU_FLOW_561-13-1',
#        'GAS_ACCU_FLOW_561-13-2', 'GAS_ACCU_FLOW_561-13-3'],
#       dtype='object')
# 561-13-4 H
# (96129, 57)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3',
#        'GAS_ACCU_FLOW_561-12-4', 'GAS_ACCU_FLOW_561-13-1',
#        'GAS_ACCU_FLOW_561-13-2', 'GAS_ACCU_FLOW_561-13-3',
#        'GAS_ACCU_FLOW_561-13-4'],
#       dtype='object')
# 561-14-1 H
# (96129, 58)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3',
#        'GAS_ACCU_FLOW_561-12-4', 'GAS_ACCU_FLOW_561-13-1',
#        'GAS_ACCU_FLOW_561-13-2', 'GAS_ACCU_FLOW_561-13-3',
#        'GAS_ACCU_FLOW_561-13-4', 'GAS_ACCU_FLOW_561-14-1'],
#       dtype='object')
# 561-14-2 H
# (96129, 59)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        'GAS_ACCU_FLOW_561-2-2', 'GAS_ACCU_FLOW_561-2-3',
#        'GAS_ACCU_FLOW_561-2-4', 'GAS_ACCU_FLOW_561-3-1',
#        'GAS_ACCU_FLOW_561-3-2', 'GAS_ACCU_FLOW_561-3-3',
#        'GAS_ACCU_FLOW_561-3-4', 'GAS_ACCU_FLOW_561-4-1',
#        'GAS_ACCU_FLOW_561-4-2', 'GAS_ACCU_FLOW_561-4-3',
#        'GAS_ACCU_FLOW_561-4-4', 'GAS_ACCU_FLOW_561-5-1',
#        'GAS_ACCU_FLOW_561-5-2', 'GAS_ACCU_FLOW_561-5-3',
#        'GAS_ACCU_FLOW_561-5-4', 'GAS_ACCU_FLOW_561-6-1',
#        'GAS_ACCU_FLOW_561-6-2', 'GAS_ACCU_FLOW_561-6-3',
#        'GAS_ACCU_FLOW_561-6-4', 'GAS_ACCU_FLOW_561-7-1',
#        'GAS_ACCU_FLOW_561-7-2', 'GAS_ACCU_FLOW_561-7-3',
#        'GAS_ACCU_FLOW_561-7-4', 'GAS_ACCU_FLOW_561-8-1',
#        'GAS_ACCU_FLOW_561-8-2', 'GAS_ACCU_FLOW_561-8-3',
#        'GAS_ACCU_FLOW_561-8-4', 'GAS_ACCU_FLOW_561-9-1',
#        'GAS_ACCU_FLOW_561-9-2', 'GAS_ACCU_FLOW_561-9-3',
#        'GAS_ACCU_FLOW_561-9-4', 'GAS_ACCU_FLOW_561-10-1',
#        'GAS_ACCU_FLOW_561-10-2', 'GAS_ACCU_FLOW_561-10-3',
#        'GAS_ACCU_FLOW_561-10-4', 'GAS_ACCU_FLOW_561-11-1',
#        'GAS_ACCU_FLOW_561-11-2', 'GAS_ACCU_FLOW_561-11-3',
#        'GAS_ACCU_FLOW_561-11-4', 'GAS_ACCU_FLOW_561-12-1',
#        'GAS_ACCU_FLOW_561-12-2', 'GAS_ACCU_FLOW_561-12-3',
#        'GAS_ACCU_FLOW_561-12-4', 'GAS_ACCU_FLOW_561-13-1',
#        'GAS_ACCU_FLOW_561-13-2', 'GAS_ACCU_FLOW_561-13-3',
#        'GAS_ACCU_FLOW_561-13-4', 'GAS_ACCU_FLOW_561-14-1',
#        'GAS_ACCU_FLOW_561-14-2'],
#       dtype='object')
# 561-14-3 H
# (96129, 60)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
# ...
# 563-21-1 H
# (96129, 336)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-19-4', 'GAS_ACCU_FLOW_563-19-5',
#        'GAS_ACCU_FLOW_563-19-6', 'GAS_ACCU_FLOW_563-20-1',
#        'GAS_ACCU_FLOW_563-20-2', 'GAS_ACCU_FLOW_563-20-3',
#        'GAS_ACCU_FLOW_563-20-4', 'GAS_ACCU_FLOW_563-20-5',
#        'GAS_ACCU_FLOW_563-20-6', 'GAS_ACCU_FLOW_563-21-1'],
#       dtype='object', length=336)
# 563-21-2 H
# (96129, 337)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-19-5', 'GAS_ACCU_FLOW_563-19-6',
#        'GAS_ACCU_FLOW_563-20-1', 'GAS_ACCU_FLOW_563-20-2',
#        'GAS_ACCU_FLOW_563-20-3', 'GAS_ACCU_FLOW_563-20-4',
#        'GAS_ACCU_FLOW_563-20-5', 'GAS_ACCU_FLOW_563-20-6',
#        'GAS_ACCU_FLOW_563-21-1', 'GAS_ACCU_FLOW_563-21-2'],
#       dtype='object', length=337)
# 563-21-3 H
# (96129, 338)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-19-6', 'GAS_ACCU_FLOW_563-20-1',
#        'GAS_ACCU_FLOW_563-20-2', 'GAS_ACCU_FLOW_563-20-3',
#        'GAS_ACCU_FLOW_563-20-4', 'GAS_ACCU_FLOW_563-20-5',
#        'GAS_ACCU_FLOW_563-20-6', 'GAS_ACCU_FLOW_563-21-1',
#        'GAS_ACCU_FLOW_563-21-2', 'GAS_ACCU_FLOW_563-21-3'],
#       dtype='object', length=338)
# 563-21-4 H
# (96129, 339)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-20-1', 'GAS_ACCU_FLOW_563-20-2',
#        'GAS_ACCU_FLOW_563-20-3', 'GAS_ACCU_FLOW_563-20-4',
#        'GAS_ACCU_FLOW_563-20-5', 'GAS_ACCU_FLOW_563-20-6',
#        'GAS_ACCU_FLOW_563-21-1', 'GAS_ACCU_FLOW_563-21-2',
#        'GAS_ACCU_FLOW_563-21-3', 'GAS_ACCU_FLOW_563-21-4'],
#       dtype='object', length=339)
# 563-21-5 H
# (96129, 340)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-20-2', 'GAS_ACCU_FLOW_563-20-3',
#        'GAS_ACCU_FLOW_563-20-4', 'GAS_ACCU_FLOW_563-20-5',
#        'GAS_ACCU_FLOW_563-20-6', 'GAS_ACCU_FLOW_563-21-1',
#        'GAS_ACCU_FLOW_563-21-2', 'GAS_ACCU_FLOW_563-21-3',
#        'GAS_ACCU_FLOW_563-21-4', 'GAS_ACCU_FLOW_563-21-5'],
#       dtype='object', length=340)
# 563-21-6 H
# (96129, 341)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-20-3', 'GAS_ACCU_FLOW_563-20-4',
#        'GAS_ACCU_FLOW_563-20-5', 'GAS_ACCU_FLOW_563-20-6',
#        'GAS_ACCU_FLOW_563-21-1', 'GAS_ACCU_FLOW_563-21-2',
#        'GAS_ACCU_FLOW_563-21-3', 'GAS_ACCU_FLOW_563-21-4',
#        'GAS_ACCU_FLOW_563-21-5', 'GAS_ACCU_FLOW_563-21-6'],
#       dtype='object', length=341)
# 563-22-1 H
# (96129, 342)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-20-4', 'GAS_ACCU_FLOW_563-20-5',
#        'GAS_ACCU_FLOW_563-20-6', 'GAS_ACCU_FLOW_563-21-1',
#        'GAS_ACCU_FLOW_563-21-2', 'GAS_ACCU_FLOW_563-21-3',
#        'GAS_ACCU_FLOW_563-21-4', 'GAS_ACCU_FLOW_563-21-5',
#        'GAS_ACCU_FLOW_563-21-6', 'GAS_ACCU_FLOW_563-22-1'],
#       dtype='object', length=342)
# 563-22-2 H
# (96129, 343)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-20-5', 'GAS_ACCU_FLOW_563-20-6',
#        'GAS_ACCU_FLOW_563-21-1', 'GAS_ACCU_FLOW_563-21-2',
#        'GAS_ACCU_FLOW_563-21-3', 'GAS_ACCU_FLOW_563-21-4',
#        'GAS_ACCU_FLOW_563-21-5', 'GAS_ACCU_FLOW_563-21-6',
#        'GAS_ACCU_FLOW_563-22-1', 'GAS_ACCU_FLOW_563-22-2'],
#       dtype='object', length=343)
# 563-22-3 H
# (96129, 344)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-20-6', 'GAS_ACCU_FLOW_563-21-1',
#        'GAS_ACCU_FLOW_563-21-2', 'GAS_ACCU_FLOW_563-21-3',
#        'GAS_ACCU_FLOW_563-21-4', 'GAS_ACCU_FLOW_563-21-5',
#        'GAS_ACCU_FLOW_563-21-6', 'GAS_ACCU_FLOW_563-22-1',
#        'GAS_ACCU_FLOW_563-22-2', 'GAS_ACCU_FLOW_563-22-3'],
#       dtype='object', length=344)
# 563-22-4 H
# (96129, 345)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-21-1', 'GAS_ACCU_FLOW_563-21-2',
#        'GAS_ACCU_FLOW_563-21-3', 'GAS_ACCU_FLOW_563-21-4',
#        'GAS_ACCU_FLOW_563-21-5', 'GAS_ACCU_FLOW_563-21-6',
#        'GAS_ACCU_FLOW_563-22-1', 'GAS_ACCU_FLOW_563-22-2',
#        'GAS_ACCU_FLOW_563-22-3', 'GAS_ACCU_FLOW_563-22-4'],
#       dtype='object', length=345)
# 563-22-5 H
# (96129, 346)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-21-2', 'GAS_ACCU_FLOW_563-21-3',
#        'GAS_ACCU_FLOW_563-21-4', 'GAS_ACCU_FLOW_563-21-5',
#        'GAS_ACCU_FLOW_563-21-6', 'GAS_ACCU_FLOW_563-22-1',
#        'GAS_ACCU_FLOW_563-22-2', 'GAS_ACCU_FLOW_563-22-3',
#        'GAS_ACCU_FLOW_563-22-4', 'GAS_ACCU_FLOW_563-22-5'],
#       dtype='object', length=346)
# 563-22-6 H
# (96129, 347)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-21-3', 'GAS_ACCU_FLOW_563-21-4',
#        'GAS_ACCU_FLOW_563-21-5', 'GAS_ACCU_FLOW_563-21-6',
#        'GAS_ACCU_FLOW_563-22-1', 'GAS_ACCU_FLOW_563-22-2',
#        'GAS_ACCU_FLOW_563-22-3', 'GAS_ACCU_FLOW_563-22-4',
#        'GAS_ACCU_FLOW_563-22-5', 'GAS_ACCU_FLOW_563-22-6'],
#       dtype='object', length=347)
# 563-23-1 H
# (96129, 348)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-21-4', 'GAS_ACCU_FLOW_563-21-5',
#        'GAS_ACCU_FLOW_563-21-6', 'GAS_ACCU_FLOW_563-22-1',
#        'GAS_ACCU_FLOW_563-22-2', 'GAS_ACCU_FLOW_563-22-3',
#        'GAS_ACCU_FLOW_563-22-4', 'GAS_ACCU_FLOW_563-22-5',
#        'GAS_ACCU_FLOW_563-22-6', 'GAS_ACCU_FLOW_563-23-1'],
#       dtype='object', length=348)
# 563-23-2 H
# (96129, 349)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-21-5', 'GAS_ACCU_FLOW_563-21-6',
#        'GAS_ACCU_FLOW_563-22-1', 'GAS_ACCU_FLOW_563-22-2',
#        'GAS_ACCU_FLOW_563-22-3', 'GAS_ACCU_FLOW_563-22-4',
#        'GAS_ACCU_FLOW_563-22-5', 'GAS_ACCU_FLOW_563-22-6',
#        'GAS_ACCU_FLOW_563-23-1', 'GAS_ACCU_FLOW_563-23-2'],
#       dtype='object', length=349)
# 563-23-3 H
# (96129, 350)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-21-6', 'GAS_ACCU_FLOW_563-22-1',
#        'GAS_ACCU_FLOW_563-22-2', 'GAS_ACCU_FLOW_563-22-3',
#        'GAS_ACCU_FLOW_563-22-4', 'GAS_ACCU_FLOW_563-22-5',
#        'GAS_ACCU_FLOW_563-22-6', 'GAS_ACCU_FLOW_563-23-1',
#        'GAS_ACCU_FLOW_563-23-2', 'GAS_ACCU_FLOW_563-23-3'],
#       dtype='object', length=350)
# 563-23-4 H
# (96129, 351)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-22-1', 'GAS_ACCU_FLOW_563-22-2',
#        'GAS_ACCU_FLOW_563-22-3', 'GAS_ACCU_FLOW_563-22-4',
#        'GAS_ACCU_FLOW_563-22-5', 'GAS_ACCU_FLOW_563-22-6',
#        'GAS_ACCU_FLOW_563-23-1', 'GAS_ACCU_FLOW_563-23-2',
#        'GAS_ACCU_FLOW_563-23-3', 'GAS_ACCU_FLOW_563-23-4'],
#       dtype='object', length=351)
# 563-24-1 H
# (96129, 352)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-22-2', 'GAS_ACCU_FLOW_563-22-3',
#        'GAS_ACCU_FLOW_563-22-4', 'GAS_ACCU_FLOW_563-22-5',
#        'GAS_ACCU_FLOW_563-22-6', 'GAS_ACCU_FLOW_563-23-1',
#        'GAS_ACCU_FLOW_563-23-2', 'GAS_ACCU_FLOW_563-23-3',
#        'GAS_ACCU_FLOW_563-23-4', 'GAS_ACCU_FLOW_563-24-1'],
#       dtype='object', length=352)
# 563-24-2 H
# (96129, 353)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-22-3', 'GAS_ACCU_FLOW_563-22-4',
#        'GAS_ACCU_FLOW_563-22-5', 'GAS_ACCU_FLOW_563-22-6',
#        'GAS_ACCU_FLOW_563-23-1', 'GAS_ACCU_FLOW_563-23-2',
#        'GAS_ACCU_FLOW_563-23-3', 'GAS_ACCU_FLOW_563-23-4',
#        'GAS_ACCU_FLOW_563-24-1', 'GAS_ACCU_FLOW_563-24-2'],
#       dtype='object', length=353)
# (96129, 353)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', 'GAS_ACCU_FLOW_561-1-1',
#        'GAS_ACCU_FLOW_561-1-2', 'GAS_ACCU_FLOW_561-1-3',
#        'GAS_ACCU_FLOW_561-1-4', 'GAS_ACCU_FLOW_561-2-1',
#        ...
#        'GAS_ACCU_FLOW_563-22-3', 'GAS_ACCU_FLOW_563-22-4',
#        'GAS_ACCU_FLOW_563-22-5', 'GAS_ACCU_FLOW_563-22-6',
#        'GAS_ACCU_FLOW_563-23-1', 'GAS_ACCU_FLOW_563-23-2',
#        'GAS_ACCU_FLOW_563-23-3', 'GAS_ACCU_FLOW_563-23-4',
#        'GAS_ACCU_FLOW_563-24-1', 'GAS_ACCU_FLOW_563-24-2'],
#       dtype='object', length=353)
#        YEAR  MONTH  DAY  HOUR  MINUTE  GAS_ACCU_FLOW_561-1-1  \
# 0      2022      8   26    20      50                    NaN
# 1      2022      8   26    21       0                    NaN
# 2      2022      8   26    21      10                    NaN
# 3      2022      8   26    21      20                    NaN
# 4      2022      8   26    21      30                    NaN
# ...     ...    ...  ...   ...     ...                    ...
# 96124  2024      6   24     9      30           0.1300000000
# 96125  2024      6   24     9      40           0.1300000000
# 96126  2024      6   24     9      50           0.1300000000
# 96127  2024      6   24    10       0           0.1300000000
# 96128  2024      6   24    10      10           0.1300000000
#
#        GAS_ACCU_FLOW_561-1-2  GAS_ACCU_FLOW_561-1-3  GAS_ACCU_FLOW_561-1-4  \
# 0                        NaN                    NaN                    NaN
# 1                        NaN                    NaN                    NaN
# 2                        NaN                    NaN                    NaN
# 3                        NaN                    NaN                    NaN
# 4                        NaN                    NaN                    NaN
# ...                      ...                    ...                    ...
# 96124           0.1300000000         116.2500000000                    NaN
# 96125           0.1300000000         116.2500000000                    NaN
# 96126           0.1300000000         116.2500000000                    NaN
# 96127           0.1300000000         116.2500000000                    NaN
# 96128                    NaN                    NaN                    NaN
#
#        GAS_ACCU_FLOW_561-2-1  ...  GAS_ACCU_FLOW_563-22-3  \
# 0                        NaN  ...                     NaN
# 1                        NaN  ...                     NaN
# 2                        NaN  ...                     NaN
# 3                        NaN  ...                     NaN
# 4                        NaN  ...                     NaN
# ...                      ...  ...                     ...
# 96124           0.1100000000  ...          107.1100000000
# 96125           0.1100000000  ...          107.1100000000
# 96126           0.1100000000  ...          107.1100000000
# 96127           0.1100000000  ...          107.1100000000
# 96128                    NaN  ...          107.1100000000
#
#        GAS_ACCU_FLOW_563-22-4  GAS_ACCU_FLOW_563-22-5  GAS_ACCU_FLOW_563-22-6  \
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 96124           80.5600000000           98.2200000000           31.0500000000
# 96125           80.5600000000           98.2200000000           31.0500000000
# 96126           80.5600000000           98.2200000000           31.0500000000
# 96127           80.5600000000           98.2200000000           31.0500000000
# 96128           80.5600000000           98.2200000000           31.0500000000
#
#        GAS_ACCU_FLOW_563-23-1  GAS_ACCU_FLOW_563-23-2  GAS_ACCU_FLOW_563-23-3  \
# 0                         NaN                     NaN            0.0000000000
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 96124            0.1000000000            0.1200000000          119.8000000000
# 96125            0.1000000000            0.1200000000          119.8000000000
# 96126            0.1000000000            0.1200000000          119.8000000000
# 96127            0.1000000000            0.1200000000          119.8000000000
# 96128            0.1000000000            0.1200000000          119.8000000000
#
#        GAS_ACCU_FLOW_563-23-4  GAS_ACCU_FLOW_563-24-1  GAS_ACCU_FLOW_563-24-2
# 0                         NaN                     NaN                     NaN
# 1                         NaN                     NaN                     NaN
# 2                         NaN                     NaN                     NaN
# 3                         NaN                     NaN                     NaN
# 4                         NaN                     NaN                     NaN
# ...                       ...                     ...                     ...
# 96124          123.3100000000          159.0500000000            0.1100000000
# 96125          123.3100000000          159.0500000000            0.1100000000
# 96126          123.3100000000          159.0500000000            0.1100000000
# 96127          123.3100000000          159.0500000000            0.1100000000
# 96128          123.3100000000          159.0500000000            0.1100000000
#
# [96129 rows x 353 columns]
