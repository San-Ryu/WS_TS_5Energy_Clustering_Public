# %% [markdown]
# ## Code Hist.

# %% [markdown]
#  - CODE : KIER Data_단순 분리 (전처리 X)
#  - DESC
#     &ensp; : int_Domain 코드의 변경에 따라,
#     &emsp; KIER 에너지 사용량 데이터를 동/층/세대별로 분리 (10분 주기)
#     &emsp; 추가적으로, Raw Data과 세대별 데이터 추출 단계에서, 아래와 같은 작업 진행
#     &emsp;&emsp; 1) Date Column에 대한 유효성 검사 및 이상 Data에 대한 소거
#     &emsp;&emsp; 1-1) Datetime 유효성 확인
#     &emsp;&emsp; 1-2) Datetime 이상치 제거
#     &emsp;&emsp; 2) HOUSE_ID_HO의 해시값을 int_house_num으로 변경 (용량 절감 목적)
#   - DATE
#     &ensp; 2023-10-12 Created
#     &ensp; 2023-11-21 Code 최신화
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 기존 모듈화된 함수 사용
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 기존 KIER 변환 관련 코드를 모두 통합
#     &ensp; 2024-01-19 Code 개선
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선, Raw로 저장
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) HOT (온수 사용량) 전용 Code 작성
#     &ensp; 2024-03-13 Code 개선
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 1) 공통코드 사용 경로 개선
#     &emsp;&emsp;&emsp;&emsp;&emsp;&emsp; 2) 적산 및 순시사용량 산출 코드 추가
#     &ensp; 2024-07-24 Error Fix : 호실별 사용량 취합시 MemoryError 발생 방지
#     &ensp; 2024-07-25 Code 개선 : HOUSE_ID Feature 도입에 따른 Code 변경

# %% [markdown]
# ## Code

# %% [markdown]
# ### 01. Init

# %% [markdown]
# #### 01-01. Module Import

# %%
#region Import_Basic Module
## Basic
import os, sys, warnings
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
os.path.dirname(os.path.abspath('./__file__'))
sys.path.append(os.path.dirname(os.path.abspath(os.path.dirname('./__file__'))))
warnings.filterwarnings('ignore')

import numpy as np, pandas as pd
from pandas import DataFrame, Series
pd.options.display.float_format = '{:.10f}'.format

import math, random

## Datetime
import time, datetime as dt
from datetime import datetime, date, timedelta

## glob
import glob, requests, json
from glob import glob

## 시각화
import matplotlib.pyplot as plt, seaborn as sns
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10, 8]

from scipy import stats

## Split, 정규화
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# K-Means 알고리즘
from sklearn.cluster import KMeans, MiniBatchKMeans

# Clustering 알고리즘의 성능 평가 측도
from sklearn import metrics
from sklearn.metrics import homogeneity_score, completeness_score, v_measure_score, adjusted_rand_score, silhouette_score, rand_score, calinski_harabasz_score, davies_bouldin_score
from sklearn.metrics.cluster import contingency_matrix

## For Web
import urllib
from urllib.request import urlopen
from urllib.parse import urlencode, unquote, quote_plus
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup

import tqdm
from tqdm.notebook import tqdm
#endregion Import_Basic Module

# %%
## Import_DL
str_tar = "tf"
## For Torch
if str_tar == "torch":
    import torch, torch.nn as nn
    from torch.nn.utils import weight_norm
    print("Torch Imported")
## For TF
elif str_tar == "tf":
    import tensorflow as tf, tensorflow_addons as tfa
    from keras.callbacks import EarlyStopping, ModelCheckpoint
    from keras.models import Sequential, load_model
    from keras_flops import get_flops
    print("Tensorflow Imported")
else:
    print("Error : Cannot be used except for Keywords")
    print(" : torch / tf")
# Out:
# Tensorflow Imported

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5382782383494674470
#  xla_global_id: -1,
#  name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 22395486208
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 8684608233463519986
#  physical_device_desc: "device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9"
#  xla_global_id: 416903419]

# %%
tf.debugging.set_log_device_placement(True)
gpus = tf.config.list_physical_devices('GPU')
if gpus:
  # 텐서플로가 첫 번째 GPU만 사용하도록 제한
  try:
    print('Using GPU')
    tf.config.set_visible_devices(gpus[0], 'GPU')
  except RuntimeError as e:
    # 프로그램 시작시에 접근 가능한 장치가 설정되어야만 합니다
    print(e)
else : 
  print('Using CPU')
# Out:
# Using GPU

# %%
## Import_Local
from Src_Dev_Common import Data_Datetime as com_date, KMA_Weather as com_KMA, KECO_AirKor as com_KECO, KASI_Holiday as com_Holi, KIER_Usage_M02 as com_KIER_M02

# %% [markdown]
# #### 01-02. Config (Directory, Params)

# %%
## Init_config
SEED = 42

np.random.seed(SEED)
tf.random.set_seed(SEED)
random.seed(SEED)
os.environ["PYTHONHASHSEED"], os.environ['TF_DETERMINISTIC_OPS'] = str(SEED), "1"

# %%
## Define Todate str
str_now_ymd = pd.datetime.now().date()
str_now_y, str_now_m, str_now_d = pd.datetime.now().year, pd.datetime.now().month, pd.datetime.now().day
str_now_hr, str_now_min = pd.datetime.now().hour, pd.datetime.now().minute

print(pd.datetime.now())
print(str(str_now_y) + " / " + str(str_now_m)  + " / " + str(str_now_d))
print(str(str_now_hr) + " : " + str(str_now_min))
# Out:
# 2024-07-26 14:39:38.499635
# 2024 / 7 / 26
# 14 : 39

# %% [markdown]
# ### 02. Data Prepare

# %%
## Dict_Domain
int_domain = 0

## Domain, ACCU/INST Column
str_domain, str_col_accu, str_col_inst = com_KIER_M02.create_domain_str(int_domain)
## Directory Root
str_dirData, str_dir_raw, str_dir_cleansed, str_dirName_bld, str_dirName_h = com_KIER_M02.create_dir_str(str_domain)

## File
str_fileRaw, str_fileRaw_hList = str('KIER_RAW_' + str_domain + '_H_ID_Adopted.csv'), str('KIER_hList_Common.csv')

print(str(os.listdir(str_dirData)) + "\n")
print(os.listdir(str_dirName_h))
# Out:
# 0 : ELEC
# ['.ipynb_checkpoints', 'BS_CONFIGURATION_202309251452.csv', 'DATE_1M_2023-10-20.csv', 'KIER 전처리 현황_2024-06-25.xlsx', 'KIER_0_Raw', 'KIER_1_Cleansed', 'KIER_2_BLD', 'KIER_3_H_ELEC', 'KIER_3_H_GAS', 'KIER_3_H_HEAT', 'KIER_3_H_HOT_FLOW', 'KIER_3_H_HOT_HEAT', 'KIER_3_H_WATER', 'KIER_ASOS_WEATHER_DAILY_202309251521.csv', 'KIER_ASOS_WEATHER_HOUR_202309251521.csv', 'KIER_DATA_OLD', 'KIER_ETC', 'KIER_hList_Comparison_2024-06-26.xlsx', 'KIER_List_Table_Column_2023-09-25.xlsx', 'KIER_Query_2023-09-25.txt', 'KMA_ASOS_119_2010_2023_1st_to CSV.csv', '[IITP] 데이터 테이블 정리 (공유 원본).docx']
#
# ['KIER_ELEC_561-1-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-1-1_INST_01_10min.csv', 'KIER_ELEC_561-1-1_INST_10MIN.csv', 'KIER_ELEC_561-1-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-1-2_INST_01_10min.csv', 'KIER_ELEC_561-1-2_INST_10MIN.csv', 'KIER_ELEC_561-1-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-1-3_INST_01_10min.csv', 'KIER_ELEC_561-1-3_INST_10MIN.csv', 'KIER_ELEC_561-1-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-1-4_INST_01_10min.csv', 'KIER_ELEC_561-1-4_INST_10MIN.csv', 'KIER_ELEC_561-10-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-10-1_INST_01_10min.csv', 'KIER_ELEC_561-10-1_INST_10MIN.csv', 'KIER_ELEC_561-10-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-10-2_INST_01_10min.csv', 'KIER_ELEC_561-10-2_INST_10MIN.csv', 'KIER_ELEC_561-10-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-10-3_INST_01_10min.csv', 'KIER_ELEC_561-10-3_INST_10MIN.csv', 'KIER_ELEC_561-10-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-10-4_INST_01_10min.csv', 'KIER_ELEC_561-10-4_INST_10MIN.csv', 'KIER_ELEC_561-11-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-11-1_INST_01_10min.csv', 'KIER_ELEC_561-11-1_INST_10MIN.csv', 'KIER_ELEC_561-11-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-11-2_INST_01_10min.csv', 'KIER_ELEC_561-11-2_INST_10MIN.csv', 'KIER_ELEC_561-11-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-11-3_INST_01_10min.csv', 'KIER_ELEC_561-11-3_INST_10MIN.csv', 'KIER_ELEC_561-11-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-11-4_INST_01_10min.csv', 'KIER_ELEC_561-11-4_INST_10MIN.csv', 'KIER_ELEC_561-12-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-12-1_INST_01_10min.csv', 'KIER_ELEC_561-12-1_INST_10MIN.csv', 'KIER_ELEC_561-12-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-12-2_INST_01_10min.csv', 'KIER_ELEC_561-12-2_INST_10MIN.csv', 'KIER_ELEC_561-12-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-12-3_INST_01_10min.csv', 'KIER_ELEC_561-12-3_INST_10MIN.csv', 'KIER_ELEC_561-12-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-12-4_INST_01_10min.csv', 'KIER_ELEC_561-12-4_INST_10MIN.csv', 'KIER_ELEC_561-13-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-13-1_INST_01_10min.csv', 'KIER_ELEC_561-13-1_INST_10MIN.csv', 'KIER_ELEC_561-13-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-13-2_INST_01_10min.csv', 'KIER_ELEC_561-13-2_INST_10MIN.csv', 'KIER_ELEC_561-13-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-13-3_INST_01_10min.csv', 'KIER_ELEC_561-13-3_INST_10MIN.csv', 'KIER_ELEC_561-13-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-13-4_INST_01_10min.csv', 'KIER_ELEC_561-13-4_INST_10MIN.csv', 'KIER_ELEC_561-14-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-14-1_INST_01_10min.csv', 'KIER_ELEC_561-14-1_INST_10MIN.csv', 'KIER_ELEC_561-14-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-14-2_INST_01_10min.csv', 'KIER_ELEC_561-14-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-14-3_INST_01_10min.csv', 'KIER_ELEC_561-14-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-14-4_INST_01_10min.csv', 'KIER_ELEC_561-15-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-15-1_INST_01_10min.csv', 'KIER_ELEC_561-15-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-15-2_INST_01_10min.csv', 'KIER_ELEC_561-15-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-15-3_INST_01_10min.csv', 'KIER_ELEC_561-15-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-15-4_INST_01_10min.csv', 'KIER_ELEC_561-16-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-16-1_INST_01_10min.csv', 'KIER_ELEC_561-16-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-16-2_INST_01_10min.csv', 'KIER_ELEC_561-16-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-16-3_INST_01_10min.csv', 'KIER_ELEC_561-16-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-16-4_INST_01_10min.csv', 'KIER_ELEC_561-17-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-17-1_INST_01_10min.csv', 'KIER_ELEC_561-17-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-17-2_INST_01_10min.csv', 'KIER_ELEC_561-17-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-17-3_INST_01_10min.csv', 'KIER_ELEC_561-17-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-17-4_INST_01_10min.csv', 'KIER_ELEC_561-18-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-18-1_INST_01_10min.csv', 'KIER_ELEC_561-18-2_ACCU_01_Raw.csv', 'KIER_ELEC_561-18-2_INST_01_10min.csv', 'KIER_ELEC_561-18-3_ACCU_01_Raw.csv', 'KIER_ELEC_561-18-3_INST_01_10min.csv', 'KIER_ELEC_561-18-4_ACCU_01_Raw.csv', 'KIER_ELEC_561-18-4_INST_01_10min.csv', 'KIER_ELEC_561-2-1_ACCU_01_Raw.csv', 'KIER_ELEC_561-2-1_INST_01_10min.csv', 'KIER_ELEC_561-2-1_INST_10MIN.csv', 'K ...

# %% [markdown]
# #### 02-01. KIER (hList)

# %%
## "KIER_01-01_Data_hList.ipynb"로부터 만들어진 Bld/F/H List
df_kier_hList = pd.read_csv(str_dir_raw + str_fileRaw_hList, index_col = 0)
# print(df_kier_hList.shape, ' /// ', df_kier_hList.columns)
# df_kier_hList

# %% [markdown]
# #### 02-02. Calculate Data Period

# %%
## 최적의 Period 계산
dt_start, dt_end = 0, 0

## 각 호별 Resampled Data 생성 및 취합
# df_kier_h_Combined = df_dt.copy()
cnt_h, df_kier_h_Combined = pd.DataFrame(), 0

list_HID = df_kier_hList['HOUSE_ID'].drop_duplicates()
for house in list_HID:
    print(str(house) + " H")

    str_file_h = str('KIER_' + str_domain + '_' + str(house) + '_ACCU_01_Raw.csv')
    df_h_tmp = pd.read_csv(str_dirName_h + str_file_h, index_col = 0)

    if dt_start == 0: 
        dt_start = df_h_tmp['METER_DATE'].min()
        print(dt_start)
    else : 
        if dt_start < df_h_tmp['METER_DATE'].min(): 
            print("True Start")
            dt_start = df_h_tmp['METER_DATE'].min()
    
    if dt_end == 0: 
        dt_end = df_h_tmp['METER_DATE'].max()
        print(dt_end)
    else : 
        if dt_start > df_h_tmp['METER_DATE'].max(): 
            print("True End")
            dt_start = df_h_tmp['METER_DATE'].max()

print('Calculated Period')
print(dt_start, ' / ', dt_end)
# Out:
# 561-1-1 H
# 2022-07-17 23:20:00
# 2024-06-05 15:30:00
# 561-1-2 H
# 561-1-3 H
# 561-1-4 H
# 561-2-1 H
# 561-2-2 H
# 561-2-3 H
# 561-2-4 H
# 561-3-1 H
# 561-3-2 H
# 561-3-3 H
# 561-3-4 H
# 561-4-1 H
# 561-4-2 H
# 561-4-3 H
# 561-4-4 H
# 561-5-1 H
# 561-5-2 H
# 561-5-3 H
# 561-5-4 H
# 561-6-1 H
# 561-6-2 H
# 561-6-3 H
# 561-6-4 H
# 561-7-1 H
# 561-7-2 H
# 561-7-3 H
# 561-7-4 H
# 561-8-1 H
# 561-8-2 H
# 561-8-3 H
# 561-8-4 H
# 561-9-1 H
# 561-9-2 H
# 561-9-3 H
# 561-9-4 H
# 561-10-1 H
# 561-10-2 H
# 561-10-3 H
# 561-10-4 H
# 561-11-1 H
# 561-11-2 H
# 561-11-3 H
# 561-11-4 H
# 561-12-1 H
# 561-12-2 H
# 561-12-3 H
# 561-12-4 H
# 561-13-1 H
# 561-13-2 H
# 561-13-3 H
# 561-13-4 H
# 561-14-1 H
# 561-14-2 H
# 561-14-3 H
# 561-14-4 H
# 561-15-1 H
# 561-15-2 H
# 561-15-3 H
# 561-15-4 H
# 561-16-1 H
# 561-16-2 H
# 561-16-3 H
# 561-16-4 H
# 561-17-1 H
# 561-17-2 H
# 561-17-3 H
# 561-17-4 H
# 561-18-1 H
# 561-18-2 H
# 561-18-3 H
# 561-18-4 H
# 562-1-1 H
# 562-1-2 H
# 562-1-3 H
# 562-1-4 H
# 562-1-5 H
# 562-1-6 H
# 562-2-1 H
# 562-2-2 H
# 562-2-3 H
# 562-2-4 H
# 562-2-5 H
# 562-2-6 H
# 562-3-1 H
# 562-3-2 H
# 562-3-3 H
# 562-3-4 H
# 562-3-5 H
# 562-3-6 H
# 562-4-1 H
# 562-4-2 H
# 562-4-3 H
# 562-4-4 H
# 562-4-5 H
# 562-4-6 H
# 562-5-1 H
# 562-5-2 H
# 562-5-3 H
# 562-5-4 H
# 562-5-5 H
# 562-5-6 H
# 562-6-1 H
# 562-6-2 H
# 562-6-3 H
# 562-6-4 H
# 562-6-5 H
# 562-6-6 H
# 562-7-1 H
# 562-7-2 H
# 562-7-3 H
# 562-7-4 H
# 562-7-5 H
# 562-7-6 H
# 562-8-1 H
# 562-8-2 H
# 562-8-3 H
# 562-8-4 H
# 562-8-5 H
# 562-8-6 H
# 562-9-1 H
# 562-9-2 H
# 562-9-3 H
# 562-9-4 H
# 562-9-5 H
# 562-9-6 H
# 562-10-1 H
# 562-10-2 H
# 562-10-3 H
# 562-10-4 H
# 562-10-5 H
# 562-10-6 H
# 562-11-1 H
# 562-11-2 H
# 562-11-3 H
# 562-11-4 H
# 562-11-5 H
# 562-11-6 H
# 562-12-1 H
# 562-12-2 H
# 562-12-3 H
# 562-12-4 H
# 562-12-5 H
# 562-12-6 H
# 562-13-1 H
# 562-13-2 H
# 562-13-3 H
# 562-13-4 H
# 562-13-5 H
# 562-13-6 H
# 562-14-1 H
# 562-14-2 H
# 562-14-3 H
# 562-14-4 H
# 562-14-5 H
# 562-14-6 H
# 562-15-1 H
# 562-15-2 H
# 562-15-3 H
# 562-15-4 H
# 562-15-5 H
# 562-15-6 H
# 562-16-1 H
# 562-16-2 H
# 562-16-3 H
# 562-16-4 H
# 562-16-5 H
# 562-16-6 H
# 562-17-1 H
# 562-17-2 H
# 562-17-3 H
# 562-17-4 H
# 562-17-5 H
# 562-17-6 H
# 562-18-1 H
# 562-18-2 H
# 562-18-3 H
# 562-18-4 H
# 562-18-5 H
# 562-18-6 H
# 562-19-1 H
# 562-19-2 H
# 562-19-3 H
# 562-19-4 H
# 562-19-5 H
# 562-19-6 H
# 562-20-1 H
# 562-20-2 H
# 562-20-3 H
# 562-20-4 H
# 562-20-5 H
# 562-20-6 H
# 562-21-1 H
# 562-21-2 H
# 562-21-3 H
# 562-21-4 H
# 562-21-5 H
# 562-21-6 H
# 562-22-1 H
# 562-22-2 H
# 562-22-3 H
# 562-22-4 H
# 562-22-5 H
# 562-22-6 H
# 562-23-1 H
# 562-23-2 H
# 562-23-3 H
# 562-23-4 H
# 562-24-1 H
# 562-24-2 H
# 563-1-1 H
# 563-1-2 H
# 563-1-3 H
# 563-1-4 H
# 563-1-5 H
# 563-1-6 H
# 563-2-1 H
# 563-2-2 H
# 563-2-3 H
# 563-2-4 H
# 563-2-5 H
# 563-2-6 H
# 563-3-1 H
# 563-3-2 H
# 563-3-3 H
# 563-3-4 H
# 563-3-5 H
# 563-3-6 H
# 563-4-1 H
# 563-4-2 H
# 563-4-3 H
# 563-4-4 H
# 563-4-5 H
# 563-4-6 H
# 563-5-1 H
# 563-5-2 H
# 563-5-3 H
# 563-5-4 H
# 563-5-5 H
# 563-5-6 H
# 563-6-1 H
# 563-6-2 H
# 563-6-3 H
# 563-6-4 H
# 563-6-5 H
# 563-6-6 H
# 563-7-1 H
# 563-7-2 H
# 563-7-3 H
# 563-7-4 H
# 563-7-5 H
# 563-7-6 H
# 563-8-1 H
# 563-8-2 H
# 563-8-3 H
# 563-8-4 H
# 563-8-5 H
# 563-8-6 H
# 563-9-1 H
# 563-9-2 H
# 563-9-3 H
# 563-9-4 H
# 563-9-5 H
# 563-9-6 H
# 563-10-1 H
# 563-10-2 H
# 563-10-3 H
# 563-10-4 H
# 563-10-5 H
# 563-10-6 H
# 563-11-1 H
# 563-11-2 H
# 563-11-3 H
# 563-11-4 H
# 563-11-5 H
# 563-11-6 H
# 563-12-1 H
# 563-12-2 H
# 563-12-3 H
# 563-12-4 H
# 563-12-5 H
# 563-12-6 H
# 563-13-1 H
# 563-13-2 H
# 563-13-3 H
# 563-13-4 H
# 563-13-5 H
# 563-13-6 H
# 563-14-1 H
# 563-14-2 H
# 563-14-3 H
# 563-14-4 H
# 563-14-5 H
# 563-14-6 H
# 563-15-1 H
# 563-15-2 H
# 563-15-3 H
# 563-15-4 H
# 563-15-5 H
# 563-15-6 H
# 563-16-1 H
# 563-16-2 H
# 563-16-3 H
# 563-16-4 H
# 563-16-5 H
# 563-16-6 H
# 563-17-1 H
# 563-17-2 H
# 563-17-3 H
# 563-17-4 H
# 563-17-5 H
# 563-17-6 H
# 563-18-1 H
# 563-18-2 H
# 563-18-3 H
# 563-18-4 H
# 563-18-5 H
# 563-18-6 H
# 563-19-1 H
# 563-19-2 H
# 563-19-3 H
# 563-19-4 H
# 563-19-5 H
# 563-19-6 H
# 563-20-1 H
# 563-20-2 H
# 563-20-3 H
# 563-20-4 H
# 563-20-5 H
# 563-20-6 H
# 563-21-1 H
# 563-21-2 H
# 563-21-3 H
# 563-21-4 H
# 563-21-5 H
# 563-21-6 H
# 563-22-1 H
# 563-22-2 H
# 563-22-3 H
# 563-22-4 H
# 563-22-5 H
# 563-22-6 H
# 563-23-1 H
# 563-23-2 H
# 563-23-3 H
# 563-23-4 H
# 563-24-1 H
# 563-24-2 H
# Calculated Period
# 2022-07-17 23:20:00  /  2024-06-05 15:30:00

# %%
## 여기서부터 실행하려 할 경우, Period를 지정해줘야함
## 계산된 Period에 대한 Date Dataframe 생성
df_kier_h_Combined = com_date.create_df_dt(pd.DataFrame(), 'METER_DATE', dt_start, dt_end, '10min')[['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE']]

## METER_DATE의 Minute이 10분 단위가 아닌 경우, 10분 단위로 변경
for i in range(0, len(df_kier_h_Combined)) : df_kier_h_Combined['MINUTE'].iloc[i] = (math.floor(df_kier_h_Combined['MINUTE'].iloc[i]/10))*10
df_kier_h_Combined
# Out:
#        YEAR  MONTH  DAY  HOUR  MINUTE
# 0      2022      7   17    23      20
# 1      2022      7   17    23      30
# 2      2022      7   17    23      40
# 3      2022      7   17    23      50
# 4      2022      7   18     0       0
# ...     ...    ...  ...   ...     ...
# 99165  2024      6    5    14      50
# 99166  2024      6    5    15       0
# 99167  2024      6    5    15      10
# 99168  2024      6    5    15      20
# 99169  2024      6    5    15      30
#
# [99170 rows x 5 columns]

# %% [markdown]
# ### 03. 적산 사용량
# 모든 호실의 사용량을 변수화하여 한 데이터셋에 Combine

# %%
list_HID = df_kier_hList['HOUSE_ID'].drop_duplicates()
for house in list_HID:
    print(str(house) + " H")

    str_col_accu_h = str_col_accu + "_" + house
    str_file = 'KIER_' + str_domain + '_' + str(house) + '_ACCU_01_Raw.csv'
    df_h_tmp = pd.read_csv(str_dirName_h + str_file, index_col = 0).reset_index()[['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE', str_col_accu_h]]

    df_kier_h_Combined = pd.merge(df_kier_h_Combined, df_h_tmp, how = 'left', on = ['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE'])
    print(df_kier_h_Combined.shape, ' /// ', df_kier_h_Combined.columns)

str_file = 'KIER_' + str_domain + '_ACCU_10MIN.csv'
df_kier_h_Combined.to_csv(str_dirName_h + str_file)
print(df_kier_h_Combined.shape, ' /// ', df_kier_h_Combined.columns)
df_kier_h_Combined
# Out:
# 561-1-1 H
# (99170, 6)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1'],
#       dtype='object')
# 561-1-2 H
# (99170, 7)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2'],
#       dtype='object')
# 561-1-3 H
# (99170, 8)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3'],
#       dtype='object')
# 561-1-4 H
# (99170, 9)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4'],
#       dtype='object')
# 561-2-1 H
# (99170, 10)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1'],
#       dtype='object')
# 561-2-2 H
# (99170, 11)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2'],
#       dtype='object')
# 561-2-3 H
# (99170, 12)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3'],
#       dtype='object')
# 561-2-4 H
# (99170, 13)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4'],
#       dtype='object')
# 561-3-1 H
# (99170, 14)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1'],
#       dtype='object')
# 561-3-2 H
# (99170, 15)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2'],
#       dtype='object')
# 561-3-3 H
# (99170, 16)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3'],
#       dtype='object')
# 561-3-4 H
# (99170, 17)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4'],
#       dtype='object')
# 561-4-1 H
# (99170, 18)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1'],
#       dtype='object')
# 561-4-2 H
# (99170, 19)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2'],
#       dtype='object')
# 561-4-3 H
# (99170, 20)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3'],
#       dtype='object')
# 561-4-4 H
# (99170, 21)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4'],
#       dtype='object')
# 561-5-1 H
# (99170, 22)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1'],
#       dtype='object')
# 561-5-2 H
# (99170, 23)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2'],
#       dtype='object')
# 561-5-3 H
# (99170, 24)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3'],
#       dtype='object')
# 561-5-4 H
# (99170, 25)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4'],
#       dtype='object')
# 561-6-1 H
# (99170, 26)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1'],
#       dtype='object')
# 561-6-2 H
# (99170, 27)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2'],
#       dtype='object')
# 561-6-3 H
# (99170, 28)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3'],
#       dtype='object')
# 561-6-4 H
# (99170, 29)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4'],
#       dtype='object')
# 561-7-1 H
# (99170, 30)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1'],
#       dtype='object')
# 561-7-2 H
# (99170, 31)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2'],
#       dtype='object')
# 561-7-3 H
# (99170, 32)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3'],
#       dtype='object')
# 561-7-4 H
# (99170, 33)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4'],
#       dtype='object')
# 561-8-1 H
# (99170, 34)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1'],
#       dtype='object')
# 561-8-2 H
# (99170, 35)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2'],
#       dtype='object')
# 561-8-3 H
# (99170, 36)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3'],
#       dtype='object')
# 561-8-4 H
# (99170, 37)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4'],
#       dtype='object')
# 561-9-1 H
# (99170, 38)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1'],
#       dtype='object')
# 561-9-2 H
# (99170, 39)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2'],
#       dtype='object')
# 561-9-3 H
# (99170, 40)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3'],
#       dtype='object')
# 561-9-4 H
# (99170, 41)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4'],
#       dtype='object')
# 561-10-1 H
# (99170, 42)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1'],
#       dtype='object')
# 561-10-2 H
# (99170, 43)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2'],
#       dtype='object')
# 561-10-3 H
# (99170, 44)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3'],
#       dtype='object')
# 561-10-4 H
# (99170, 45)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4'],
#       dtype='object')
# 561-11-1 H
# (99170, 46)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1'],
#       dtype='object')
# 561-11-2 H
# (99170, 47)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1', 'ELEC_ACTUAL_ACCU_EFF_561-11-2'],
#       dtype='object')
# 561-11-3 H
# (99170, 48)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1', 'ELEC_ACTUAL_ACCU_EFF_561-11-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-3'],
#       dtype='object')
# 561-11-4 H
# (99170, 49)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1', 'ELEC_ACTUAL_ACCU_EFF_561-11-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-3', 'ELEC_ACTUAL_ACCU_EFF_561-11-4'],
#       dtype='object')
# 561-12-1 H
# (99170, 50)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1', 'ELEC_ACTUAL_ACCU_EFF_561-11-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-3', 'ELEC_ACTUAL_ACCU_EFF_561-11-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-12-1'],
#       dtype='object')
# 561-12-2 H
# (99170, 51)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1', 'ELEC_ACTUAL_ACCU_EFF_561-11-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-3', 'ELEC_ACTUAL_ACCU_EFF_561-11-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-12-1', 'ELEC_ACTUAL_ACCU_EFF_561-12-2'],
#       dtype='object')
# 561-12-3 H
# (99170, 52)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1', 'ELEC_ACTUAL_ACCU_EFF_561-11-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-3', 'ELEC_ACTUAL_ACCU_EFF_561-11-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-12-1', 'ELEC_ACTUAL_ACCU_EFF_561-12-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-12-3'],
#       dtype='object')
# 561-12-4 H
# (99170, 53)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-1', 'ELEC_ACTUAL_ACCU_EFF_561-9-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-9-3', 'ELEC_ACTUAL_ACCU_EFF_561-9-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-1', 'ELEC_ACTUAL_ACCU_EFF_561-10-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-10-3', 'ELEC_ACTUAL_ACCU_EFF_561-10-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-1', 'ELEC_ACTUAL_ACCU_EFF_561-11-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-11-3', 'ELEC_ACTUAL_ACCU_EFF_561-11-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-12-1', 'ELEC_ACTUAL_ACCU_EFF_561-12-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-12-3', 'ELEC_ACTUAL_ACCU_EFF_561-12-4'],
#       dtype='object')
# 561-13-1 H
# (99170, 54)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1', 'ELEC_ACTUAL_ACCU_EFF_561-2-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-3', 'ELEC_ACTUAL_ACCU_EFF_561-2-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-1', 'ELEC_ACTUAL_ACCU_EFF_561-3-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-3-3', 'ELEC_ACTUAL_ACCU_EFF_561-3-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-1', 'ELEC_ACTUAL_ACCU_EFF_561-4-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-4-3', 'ELEC_ACTUAL_ACCU_EFF_561-4-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-1', 'ELEC_ACTUAL_ACCU_EFF_561-5-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-5-3', 'ELEC_ACTUAL_ACCU_EFF_561-5-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-1', 'ELEC_ACTUAL_ACCU_EFF_561-6-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-6-3', 'ELEC_ACTUAL_ACCU_EFF_561-6-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-1', 'ELEC_ACTUAL_ACCU_EFF_561-7-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-7-3', 'ELEC_ACTUAL_ACCU_EFF_561-7-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-1', 'ELEC_ACTUAL_ACCU_EFF_561-8-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-8-3', 'ELEC_ACTUAL_ACCU_EFF_561-8-4',
# ...
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-20-3', 'ELEC_ACTUAL_ACCU_EFF_563-20-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-20-5', 'ELEC_ACTUAL_ACCU_EFF_563-20-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-1', 'ELEC_ACTUAL_ACCU_EFF_563-21-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-3', 'ELEC_ACTUAL_ACCU_EFF_563-21-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-5', 'ELEC_ACTUAL_ACCU_EFF_563-21-6'],
#       dtype='object', length=341)
# 563-22-1 H
# (99170, 342)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-20-4', 'ELEC_ACTUAL_ACCU_EFF_563-20-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-20-6', 'ELEC_ACTUAL_ACCU_EFF_563-21-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-2', 'ELEC_ACTUAL_ACCU_EFF_563-21-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-4', 'ELEC_ACTUAL_ACCU_EFF_563-21-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-6', 'ELEC_ACTUAL_ACCU_EFF_563-22-1'],
#       dtype='object', length=342)
# 563-22-2 H
# (99170, 343)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-20-5', 'ELEC_ACTUAL_ACCU_EFF_563-20-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-1', 'ELEC_ACTUAL_ACCU_EFF_563-21-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-3', 'ELEC_ACTUAL_ACCU_EFF_563-21-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-5', 'ELEC_ACTUAL_ACCU_EFF_563-21-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-1', 'ELEC_ACTUAL_ACCU_EFF_563-22-2'],
#       dtype='object', length=343)
# 563-22-3 H
# (99170, 344)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-20-6', 'ELEC_ACTUAL_ACCU_EFF_563-21-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-2', 'ELEC_ACTUAL_ACCU_EFF_563-21-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-4', 'ELEC_ACTUAL_ACCU_EFF_563-21-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-6', 'ELEC_ACTUAL_ACCU_EFF_563-22-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-2', 'ELEC_ACTUAL_ACCU_EFF_563-22-3'],
#       dtype='object', length=344)
# 563-22-4 H
# (99170, 345)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-21-1', 'ELEC_ACTUAL_ACCU_EFF_563-21-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-3', 'ELEC_ACTUAL_ACCU_EFF_563-21-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-5', 'ELEC_ACTUAL_ACCU_EFF_563-21-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-1', 'ELEC_ACTUAL_ACCU_EFF_563-22-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-3', 'ELEC_ACTUAL_ACCU_EFF_563-22-4'],
#       dtype='object', length=345)
# 563-22-5 H
# (99170, 346)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-21-2', 'ELEC_ACTUAL_ACCU_EFF_563-21-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-4', 'ELEC_ACTUAL_ACCU_EFF_563-21-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-6', 'ELEC_ACTUAL_ACCU_EFF_563-22-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-2', 'ELEC_ACTUAL_ACCU_EFF_563-22-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-4', 'ELEC_ACTUAL_ACCU_EFF_563-22-5'],
#       dtype='object', length=346)
# 563-22-6 H
# (99170, 347)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-21-3', 'ELEC_ACTUAL_ACCU_EFF_563-21-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-5', 'ELEC_ACTUAL_ACCU_EFF_563-21-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-1', 'ELEC_ACTUAL_ACCU_EFF_563-22-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-3', 'ELEC_ACTUAL_ACCU_EFF_563-22-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-5', 'ELEC_ACTUAL_ACCU_EFF_563-22-6'],
#       dtype='object', length=347)
# 563-23-1 H
# (99170, 348)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-21-4', 'ELEC_ACTUAL_ACCU_EFF_563-21-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-21-6', 'ELEC_ACTUAL_ACCU_EFF_563-22-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-2', 'ELEC_ACTUAL_ACCU_EFF_563-22-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-4', 'ELEC_ACTUAL_ACCU_EFF_563-22-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-6', 'ELEC_ACTUAL_ACCU_EFF_563-23-1'],
#       dtype='object', length=348)
# 563-23-2 H
# (99170, 349)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-21-5', 'ELEC_ACTUAL_ACCU_EFF_563-21-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-1', 'ELEC_ACTUAL_ACCU_EFF_563-22-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-3', 'ELEC_ACTUAL_ACCU_EFF_563-22-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-5', 'ELEC_ACTUAL_ACCU_EFF_563-22-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-1', 'ELEC_ACTUAL_ACCU_EFF_563-23-2'],
#       dtype='object', length=349)
# 563-23-3 H
# (99170, 350)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-21-6', 'ELEC_ACTUAL_ACCU_EFF_563-22-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-2', 'ELEC_ACTUAL_ACCU_EFF_563-22-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-4', 'ELEC_ACTUAL_ACCU_EFF_563-22-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-6', 'ELEC_ACTUAL_ACCU_EFF_563-23-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-2', 'ELEC_ACTUAL_ACCU_EFF_563-23-3'],
#       dtype='object', length=350)
# 563-23-4 H
# (99170, 351)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-22-1', 'ELEC_ACTUAL_ACCU_EFF_563-22-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-3', 'ELEC_ACTUAL_ACCU_EFF_563-22-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-5', 'ELEC_ACTUAL_ACCU_EFF_563-22-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-1', 'ELEC_ACTUAL_ACCU_EFF_563-23-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-3', 'ELEC_ACTUAL_ACCU_EFF_563-23-4'],
#       dtype='object', length=351)
# 563-24-1 H
# (99170, 352)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-22-2', 'ELEC_ACTUAL_ACCU_EFF_563-22-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-4', 'ELEC_ACTUAL_ACCU_EFF_563-22-5',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-6', 'ELEC_ACTUAL_ACCU_EFF_563-23-1',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-2', 'ELEC_ACTUAL_ACCU_EFF_563-23-3',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-4', 'ELEC_ACTUAL_ACCU_EFF_563-24-1'],
#       dtype='object', length=352)
# 563-24-2 H
# (99170, 353)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-22-3', 'ELEC_ACTUAL_ACCU_EFF_563-22-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-5', 'ELEC_ACTUAL_ACCU_EFF_563-22-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-1', 'ELEC_ACTUAL_ACCU_EFF_563-23-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-3', 'ELEC_ACTUAL_ACCU_EFF_563-23-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-24-1', 'ELEC_ACTUAL_ACCU_EFF_563-24-2'],
#       dtype='object', length=353)
# (99170, 353)  ///  Index(['YEAR', 'MONTH', 'DAY', 'HOUR', 'MINUTE',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-1', 'ELEC_ACTUAL_ACCU_EFF_561-1-2',
#        'ELEC_ACTUAL_ACCU_EFF_561-1-3', 'ELEC_ACTUAL_ACCU_EFF_561-1-4',
#        'ELEC_ACTUAL_ACCU_EFF_561-2-1',
#        ...
#        'ELEC_ACTUAL_ACCU_EFF_563-22-3', 'ELEC_ACTUAL_ACCU_EFF_563-22-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-22-5', 'ELEC_ACTUAL_ACCU_EFF_563-22-6',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-1', 'ELEC_ACTUAL_ACCU_EFF_563-23-2',
#        'ELEC_ACTUAL_ACCU_EFF_563-23-3', 'ELEC_ACTUAL_ACCU_EFF_563-23-4',
#        'ELEC_ACTUAL_ACCU_EFF_563-24-1', 'ELEC_ACTUAL_ACCU_EFF_563-24-2'],
#       dtype='object', length=353)
#        YEAR  MONTH  DAY  HOUR  MINUTE  ELEC_ACTUAL_ACCU_EFF_561-1-1  \
# 0      2022      7   17    23      20                798.6900000000
# 1      2022      7   17    23      30                798.8600000000
# 2      2022      7   17    23      40                799.0200000000
# 3      2022      7   17    23      50                799.1600000000
# 4      2022      7   18     0       0                799.3000000000
# ...     ...    ...  ...   ...     ...                           ...
# 99165  2024      6    5    14      50              10755.0000000000
# 99166  2024      6    5    15       0              10755.0400000000
# 99167  2024      6    5    15      10              10755.0700000000
# 99168  2024      6    5    15      20              10755.1200000000
# 99169  2024      6    5    15      30              10755.1700000000
#
#        ELEC_ACTUAL_ACCU_EFF_561-1-2  ELEC_ACTUAL_ACCU_EFF_561-1-3  \
# 0                    650.6700000000                452.0000000000
# 1                    650.8400000000                452.0400000000
# 2                    651.0200000000                452.0700000000
# 3                    651.2500000000                452.1000000000
# 4                    651.4600000000                452.1200000000
# ...                             ...                           ...
# 99165               9350.7800000000               7648.3000000000
# 99166               9350.8400000000               7648.5300000000
# 99167               9350.9000000000               7648.8700000000
# 99168               9350.9700000000               7649.1600000000
# 99169               9351.0700000000               7649.2900000000
#
#        ELEC_ACTUAL_ACCU_EFF_561-1-4  ELEC_ACTUAL_ACCU_EFF_561-2-1  ...  \
# 0                    812.2400000000                664.2700000000  ...
# 1                    812.5300000000                664.4500000000  ...
# 2                    812.7400000000                664.5800000000  ...
# 3                    812.9800000000                664.7200000000  ...
# 4                    813.2500000000                664.8700000000  ...
# ...                             ...                           ...  ...
# 99165              10798.9000000000              11286.6500000000  ...
# 99166              10798.9300000000              11286.7500000000  ...
# 99167              10798.9600000000              11286.8200000000  ...
# 99168              10798.9800000000              11286.8900000000  ...
# 99169              10799.0000000000              11286.9700000000  ...
#
#        ELEC_ACTUAL_ACCU_EFF_563-22-3  ELEC_ACTUAL_ACCU_EFF_563-22-4  \
# 0                     524.5100000000                 462.4000000000
# 1                     524.6600000000                 462.5100000000
# 2                     524.7800000000                 462.6100000000
# 3                     524.8800000000                 462.7100000000
# 4                     525.0000000000                 462.8100000000
# ...                              ...                            ...
# 99165                            NaN                            NaN
# 99166                            NaN                            NaN
# 99167                            NaN                            NaN
# 99168                            NaN                6405.4600000000
# 99169                            NaN                            NaN
#
#        ELEC_ACTUAL_ACCU_EFF_563-22-5  ELEC_ACTUAL_ACCU_EFF_563-22-6  \
# 0                     489.8000000000                 470.6400000000
# 1                     489.8300000000                 470.6800000000
# 2                     489.8500000000                 470.7200000000
# 3                     489.8900000000                 470.7500000000
# 4                     489.9300000000                 470.7900000000
# ...                              ...                            ...
# 99165                7520.4100000000                            NaN
# 99166                7520.4500000000                            NaN
# 99167                7520.5300000000                            NaN
# 99168                7520.5800000000                            NaN
# 99169                7520.6700000000                            NaN
#
#        ELEC_ACTUAL_ACCU_EFF_563-23-1  ELEC_ACTUAL_ACCU_EFF_563-23-2  \
# 0                     358.2800000000                 523.9700000000
# 1                     358.3300000000                 524.0500000000
# 2                     358.3900000000                 524.1100000000
# 3                     358.4400000000                 524.1700000000
# 4                     358.4800000000                 524.2300000000
# ...                              ...                            ...
# 99165                6486.7300000000                            NaN
# 99166                            NaN                            NaN
# 99167                            NaN                            NaN
# 99168                6486.7800000000                            NaN
# 99169                            NaN                            NaN
#
#        ELEC_ACTUAL_ACCU_EFF_563-23-3  ELEC_ACTUAL_ACCU_EFF_563-23-4  \
# 0                     441.8800000000                 380.0800000000
# 1                     441.9400000000                 380.1400000000
# 2                     441.9900000000                            NaN
# 3                     442.0400000000                 380.2400000000
# 4                     442.0800000000                 380.2900000000
# ...                              ...                            ...
# 99165                            NaN                            NaN
# 99166                            NaN                            NaN
# 99167                            NaN                            NaN
# 99168                6719.9600000000                            NaN
# 99169                            NaN                            NaN
#
#        ELEC_ACTUAL_ACCU_EFF_563-24-1  ELEC_ACTUAL_ACCU_EFF_563-24-2
# 0                     393.9300000000                 511.9200000000
# 1                     393.9600000000                 512.0200000000
# 2                     393.9800000000                 512.1100000000
# 3                     394.0100000000                 512.2000000000
# 4                     394.0400000000                 512.2800000000
# ...                              ...                            ...
# 99165                            NaN                            NaN
# 99166                            NaN                            NaN
# 99167                            NaN                            NaN
# 99168                            NaN                7788.9200000000
# 99169                            NaN                            NaN
#
# [99170 rows x 353 columns]

# %%
# ## [미사용] Interpolation 후 수행해야할 연산
# list_col = df_kier_h_Combined.columns[5:] ## 세대별 에너지 사용량 Columns
# df_kier_Calc = df_kier_h_Combined[list_col]
# print(list_col)

# ## df_kier_h_Combined는 차후 "04. 순시사용량" 과정에서 재활용되므로, 
# ## df_kier_extract를 별도 선언 및 추출
# df_kier_extract = df_kier_h_Combined

# ## 사용량 평균 및 합계 Column 추가
# df_kier_extract['MEAN_OF_ACCU'], df_kier_extract['SUM_OF_ACCU'] = df_kier_Calc.mean(axis = 1), df_kier_Calc.sum(axis = 1)

# str_file = 'KIER_' + str_domain + '_ACCU_10MIN.csv'
# df_kier_extract.to_csv(str_dirName_h + str_file)
# print(df_kier_extract.isnull().sum())
# df_kier_extract
